# %%
from pathlib import Path
import csv
import pandas as pd
from datetime import datetime

# %%
# loading the data

notebook_dir = Path.cwd()
# the data is located in data/raw folder
data_dir = notebook_dir.parent.absolute() / 'data_raw' 
csv_dir = notebook_dir.parent.absolute() / 'clean_csvs' 

#convert txt of instagram texts to strings
path_raw = data_dir / 'aarush_messenger.txt'
path_csv_grouped = csv_dir / 'messages_grouped_by_user' / 'aarush-messenger-grouped.csv'
path_csv_separate = csv_dir / 'messages_separate' / 'aarush-messenger-separate.csv'

# %%
with open(path_raw) as fp:
    messenger_data = fp.read()

# %%
# remove the beginning part of the txt file
beginIndex = messenger_data.find('\n\n\n')
messenger_data = messenger_data[beginIndex + 3:]
messenger_data = messenger_data.strip()

# %%
# mark the usernames with a special key
special_key = 'Nnọọ' #when would we ever say hello in Igbo in our chat? it's more likely than you think
messenger_data = messenger_data.replace('\nAarush Agte', '\n' + special_key + 'Aarush Agte')
messenger_data = messenger_data.replace('\nSamyukta Athreya', '\n' + special_key + 'Samyukta Athreya')

# %%
while messenger_data.find('\n\n') != -1:
    messenger_data = messenger_data.replace('\n\n', '\n')

# %%
filename = "output.txt"

# Open a file in write mode ('w') and write the string to it
with open(filename, 'w') as file:
    file.write(messenger_data)

print(f"String has been written to {filename}")
# Out:
# String has been written to output.txt

# %%
def getWordCount(messageLine):
    messageLine = messageLine.strip()
    return(len(messageLine.split(' ')))

# %%
# figuring out how to read the messenger data
#columns for csv:
#'date', 'user', 'text', 'word count', 'number of separated texts', 'reactions', 'platform'
#type of reply options: story reply, reel, normal message

users = {'Samyukta Athreya', 'Aarush Agte'}
months = {'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'}
user, date, text, word_count, num_sep_texts, reactions = '', '', '', '', '', ''

message_dict = []

for message_block in messenger_data.split(special_key): #split data by user
    for line in message_block.splitlines():

        line = line.strip()

        #check if it's a user line
        if line == 'Samyukta Athreya':
            user = 'Samyukta'
        elif line == 'Aarush Agte':
            user = 'Aarush'

        #check if it's a date line
        elif line[:3] in months or line[1:4] in months:
            date = line
        
        #check if it's a reaction line
        elif line.find('Samyukta Athreya') != -1 or line.find('Aarush Agte') != -1:
            nameIndex = line.find('Samyukta Athreya')
            if nameIndex == -1:
                nameIndex = line.find('Aarush Agte')
            reactions = line[:nameIndex]
        
        else:
            text = line
            word_count = getWordCount(line)
    res = {
        'date' : date, 
        'user' : user, 
        'text' : text, 
        'word count' : word_count, 
        'number of separated texts' : num_sep_texts, 
        'reactions' : reactions,  
        'platform' : 'Messenger'
        }
    user, date, text, word_count, num_sep_texts, reactions = '', '', '', '', '', ''
    message_dict.append(res)
print(message_dict)
# Out:
# [{'date': 'Jan 12, 2023 2:18:34pm', 'user': 'Aarush', 'text': '', 'word count': '', 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:58:31pm', 'user': 'Samyukta', 'text': 'SH i connected the dots', 'word count': 5, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:52:42pm', 'user': 'Aarush', 'text': 'THATS WHY IT WAS FUNNY', 'word count': 5, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:52:37pm', 'user': 'Aarush', 'text': 'like string theory', 'word count': 3, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:52:34pm', 'user': 'Aarush', 'text': 'OMG UNRAVEL', 'word count': 2, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:51:21pm', 'user': 'Samyukta', 'text': 'ALSO HE IS RISEN IS JUST EASTER', 'word count': 7, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:34:59pm', 'user': 'Samyukta', 'text': 'This is killing me -John H', 'word count': 6, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:34:51pm', 'user': 'Samyukta', 'text': '', 'word count': '', 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 12, 2023 1:34:44pm', 'user': 'Samyukta', 'text': 'My discord isn’t working', 'word count': 4, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Mar 03, 2022 7:48:55am', 'user': 'Aarush', 'text': '', 'word count': '', 'number of separated texts': '', 'reactions': '❤', 'platform': 'Messenger'}, {'date': 'Mar 03, 2022 7:47:50am', 'user': 'Aarush', 'text': '', 'word count': 1, 'number of separated texts': '', 'reactions': '❤', 'platform': 'Messenger'}, {'date': 'Feb 18, 2022 10:26:51am', 'user': 'Samyukta', 'text': 'https://colonist.io/#Yhp2', 'word count': 1, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Feb 17, 2022 4:27:05pm', 'user': 'Aarush', 'text': 'ur gay', 'word count': 2, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Feb 17, 2022 4:16:13pm', 'user': 'Samyukta', 'text': 'U did not heed my warning', 'word count': 6, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Feb 17, 2022 2:34:46pm', 'user': 'Aarush', 'text': 'ur so gay', 'word count': 3, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Feb 17, 2022 2:14:41pm', 'user': 'Samyukta', 'text': 'Get a lot of wheat and stone it’s how Tiffany beats everyone', 'word count': 12, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Feb 07, 2022 10:50:05pm', 'user': 'Samyukta', 'text': '', 'word count': '', 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 27, 2022 11:03:11am', 'user': 'Samyukta', 'text': 'Thanks kingaloo', 'word count': 2, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 27, 2022 8:39:00am', 'user': 'Aarush', 'text': 'old wordles', 'word count': 2, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 27, 2022 8:38:58am', 'user': 'Aarush', 'text': 'https://www.devangthakkar.com/wordle_archive/?198', 'word count': 1, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 16, 2022 9:49:51pm', 'user': 'Aarush', 'text': 'they/themnarch', 'word count': 1, 'number of separated texts': '', 'reactions': '❤', 'platform': 'Messenger'}, {'date': 'Jan 16, 2022 9:49:47pm', 'user': 'Aarush', 'text': '', 'word count': 1, 'number of separated texts': '', 'reactions': '', 'platform': 'Messenger'}, {'date': 'Jan 16, 2022 9:49:46pm', 'user': 'Aarush', 'text': 'pop off queen !', 'word count': 4, 'number of separated texts ...

# %%
#save dictionary as csv
aarushMsngrCSV = open(path_csv_grouped, 'w')
writer = csv.writer(aarushMsngrCSV)
writer.writerow(['date', 'user', 'text', 'word count', 'number of separated texts', 'reactions', 'platform'])
for dictionary in message_dict:
    writer.writerow(dictionary.values())
aarushMsngrCSV.close()
aarushMsngrCSV = open(path_csv_grouped, 'r')
print("The content of the csv file is:")
print(aarushMsngrCSV.read())
aarushMsngrCSV.close()
# Out:
# The content of the csv file is:
# date,user,text,word count,number of separated texts,reactions,platform
#
# "Jan 12, 2023 2:18:34pm",Aarush,,,,,Messenger
#
# "Jan 12, 2023 1:58:31pm",Samyukta,SH i connected the dots,5,,,Messenger
#
# "Jan 12, 2023 1:52:42pm",Aarush,THATS WHY IT WAS FUNNY,5,,,Messenger
#
# "Jan 12, 2023 1:52:37pm",Aarush,like string theory,3,,,Messenger
#
# "Jan 12, 2023 1:52:34pm",Aarush,OMG UNRAVEL,2,,,Messenger
#
# "Jan 12, 2023 1:51:21pm",Samyukta,ALSO HE IS RISEN IS JUST EASTER,7,,,Messenger
#
# "Jan 12, 2023 1:34:59pm",Samyukta,This is killing me -John H,6,,,Messenger
#
# "Jan 12, 2023 1:34:51pm",Samyukta,,,,,Messenger
#
# "Jan 12, 2023 1:34:44pm",Samyukta,My discord isn’t working,4,,,Messenger
#
# "Mar 03, 2022 7:48:55am",Aarush,,,,❤,Messenger
#
# "Mar 03, 2022 7:47:50am",Aarush,,1,,❤,Messenger
#
# "Feb 18, 2022 10:26:51am",Samyukta,https://colonist.io/#Yhp2,1,,,Messenger
#
# "Feb 17, 2022 4:27:05pm",Aarush,ur gay,2,,,Messenger
#
# "Feb 17, 2022 4:16:13pm",Samyukta,U did not heed my warning,6,,,Messenger
#
# "Feb 17, 2022 2:34:46pm",Aarush,ur so gay,3,,,Messenger
#
# "Feb 17, 2022 2:14:41pm",Samyukta,Get a lot of wheat and stone it’s how Tiffany beats everyone,12,,,Messenger
#
# "Feb 07, 2022 10:50:05pm",Samyukta,,,,,Messenger
#
# "Jan 27, 2022 11:03:11am",Samyukta,Thanks kingaloo,2,,,Messenger
#
# "Jan 27, 2022 8:39:00am",Aarush,old wordles,2,,,Messenger
#
# "Jan 27, 2022 8:38:58am",Aarush,https://www.devangthakkar.com/wordle_archive/?198,1,,,Messenger
#
# "Jan 16, 2022 9:49:51pm",Aarush,they/themnarch,1,,❤,Messenger
#
# "Jan 16, 2022 9:49:47pm",Aarush,,1,,,Messenger
#
# "Jan 16, 2022 9:49:46pm",Aarush,pop off queen !,4,,,Messenger
#
# "Jan 16, 2022 9:49:42pm",Aarush,omg,1,,,Messenger
#
# "Jan 16, 2022 9:48:28pm",Samyukta,Ok well I literally have it so,7,,,Messenger
#
# "Jan 16, 2022 9:48:14pm",Samyukta,YEA LOL,2,,,Messenger
#
# "Jan 16, 2022 9:44:34pm",Aarush,i dont beleiev that at all,6,,,Messenger
#
# "Jan 16, 2022 9:44:30pm",Aarush,tumblr trash right,3,,,Messenger
#
# "Jan 16, 2022 9:44:27pm",Aarush,its probably like,3,,,Messenger
#
# "Jan 16, 2022 9:43:58pm",Aarush,,,,,Messenger
#
# "Jan 16, 2022 9:34:49pm",Samyukta,i know three book characters with purple eyes and all of them are like supposed to be really hot headcanoncailly,20,,,Messenger
#
# "Jan 16, 2022 9:34:24pm",Samyukta,and it's not real i think but whatever,8,,,Messenger
#
# "Jan 16, 2022 9:34:18pm",Samyukta,and everyone was like OMGGGGGGG i want that,8,,,Messenger
#
# "Jan 16, 2022 9:34:10pm",Samyukta,,1,,,Messenger
#
# "Jan 16, 2022 9:33:25pm",Samyukta,there was this post like,5,,,Messenger
#
# "Jan 16, 2022 9:33:22pm",Samyukta,when i was in seventh grade,6,,,Messenger
#
# "Jan 16, 2022 9:33:21pm",Aarush,brb,1,,,Messenger
#
# "Jan 16, 2022 9:33:20pm",Aarush,okay bob,2,,,Messenger
#
# "Jan 16, 2022 9:33:06pm",Samyukta,PURPLE,1,,,Messenger
#
# "Jan 16, 2022 9:32:57pm",Samyukta,My eyes are so prominent,5,,,Messenger
#
# "Jan 16, 2022 9:32:47pm",Samyukta,Ohhhhh,1,,,Messenger
#
# "Jan 16, 2022 9:32:40pm",Aarush,i have like 50 pics of u,7,,,Messenger
#
# "Jan 16, 2022 9:32:35pm",Aarush,no i meant what eye color do u want,9,,,Messenger
#
# "Jan 16, 2022 9:32:24pm",Samyukta,,,,,Messenger
#
# "Jan 16, 2022 9:32:13pm",Samyukta,H,1,,,Messenger
#
# "Jan 16, 2022 9:32:08pm",Aarush,,1,,,Messenger
#
# "Jan 04, 2022 12:00:57am",Aarush,,,,,Messenger
#
# "Jan 03, 2022 10:31:25pm",Samyukta,https://www.youtube.com/watch?v=cPQa2jTM2E8,1,,,Messenger
#
# "Jan 01, 2022 7:13:05pm",Aarush,no.,1,,,Messenger
#
# "Jan 01, 2022 6:15:07pm",Samyukta,,,,,Messenger
#
# "Jan 01, 2022 6:15:04pm",Samyukta,You need to get chairs.,5,,,Messenger
#
# "Jan 01, 2022 5:57:37pm",Aarush,,,,,Messenger
#
# "Jan 01, 2022 4:49:38pm",Aarush,omg,1,,,Messenger
#
# "Jan 01, 2022 4:49:26pm",Samyukta,Now what do I do,5,,,Messenger
#
# "Jan 01, 2022 4:49:19pm",Samyukta,I’m at ur house,4,,,Messenger
#
# "Jan 01, 2022 4:37:47pm",Aarush,chem ref.....,2,,,Messenger
#
# "Jan 01, 2022 4:37:41pm",Aarush,omg,1,,,Messenger
#
# "Jan 01, 2022 4:37:32pm",Samyukta,,,,,Messenger
#
# "Jan 01, 2022 4:35:15pm",Aarush,or it's like mouthwash i think but should work,9,,,Messenger
#
# "Jan 01, 2022 4:35:00pm",Aarush,yeah,1,,,Messenger
#
# "Jan 01, 2022 4:33:48pm",Samyukta,anytime vagene,2,,,Messenger
#
# "Jan 01, 2022 4:33:40pm",Samyukta,Cause I can pick it up,6,,,Messenger
#
# "Jan 01, 2022 4:33:34pm",Samyukta,Hey do u have hydrogen peroxide,6,,,Messenger
#
# "Jan 01, 2022 4:33:20pm",Aarush,hey no worries bob,4,,,Messenger
#
# "Jan 01, 2022 4:32:56pm",Samyukta,Hey finding iodine tincture is kinda difficult so I’ll be late,11,,,Messenger
#
# "Jan 01, 2022 3:40:47pm",Aarush,us,1,,,Messenger
#
# "Jan 01, 2022 3:08:51pm",Samyukta,https://www.youtube.com/watch?v=8R_7KCtShkU,1,,,Messenger
#
# "Dec 31, 2021 11:24:49pm",Samyukta,valid,1,,,Messenger
#
# "Dec 31, 2021 11:20:23pm",Aarush,piss,1,,,Messenger
#
# "Dec 31, 2021 11:20:21pm",Aarush,uh,1,,,Messenger
#
# "Dec 31, 2021 11:18:05pm",Samyukta,why friend,2,,,Messenger
#
# "Dec 31, 2021 11:17:17pm",Aarush,my room smells like piss,5,,,Messenger
#
# "Dec 31, 2021 11:17:12pm",Aarush,,,,,Messenger
#
# "Dec 31, 2021 11:17:05pm",Aarush,shore,1,,,Messenger
#
# "Dec 31, 2021 11:17:02pm",Samyukta,or whenever my thraot dies,5,,,Messenger
#
# "Dec 31, 2021 11:16:49pm",Samyukta,so lets call at like 11:45,6,,,Messenger
#
# "Dec 31, 2021 11:16:47pm",Aarush,omg go off,3,,,Messenger
#
# "Dec 31, 2021 11:16:42pm",Samyukta,i am currently karaoking cause my parents rnt home and i can scream,13,,,Messenger
#
# "Dec 31, 2021 11:16:29pm",Samyukta,sorry i am very calfiornian,5,,,Messenger
#
# "Dec 31, 2021 11:12:23pm",Aarush,or call that's cool too,5,,,Messenger
#
# "Dec 31, 2021 11:12:19pm",Aarush,(be Californian),2,,,Messenger
#
# "Dec 31, 2021 11:12:13pm",Aarush,hey Bob when r we gonna cal,7,,,Messenger
#
# "Dec 30, 2021 4:02:13pm",Aarush,link is on discord for buying,6,,,Messenger
#
# "Dec 30, 2021 4:02:04pm",Aarush,also when u buy tickets make sure it's 11:30am,9,,,Messenger
#
# "Dec 30, 2021 3:26:01pm",Aarush,also take a picture of ur vaccine card,8,,,Messenger
#
# "Dec 30, 2021 3:24:52pm",Aarush,ok,1,,,Messenger
#
# "Dec 30, 2021 3:12:23pm",Samyukta,Omg okay I’ll buy when I get home,8,,,Messenger
#
# "Dec 30, 2021 3:12:11pm",Samyukta,You have to buy it online???,6,,,Messenger
#
# "Dec 30, 2021 3:06:40pm",Aarush,did u buy the ice skating ticket yet,8,,,Messenger
#
# "Dec 30, 2021 1:10:42pm",Samyukta,This message was unsent,4,,,Messenger
#
# "Dec 30, 2021 1:10:40pm",Samyukta,This message was unsent,4,,,Messenger
#
# "Dec 29, 2021 12:44:47am",Aarush,can u check discord,4,,,Messenger
#
# "Dec 28, 2021 6:35:02pm",Samyukta,As u should,3,,,Messenger
#
# "Dec 28, 2021 6:34:43pm",Aarush,sory,1,,,Messenger
#
# "Dec 28, 2021 6:34:41pm",Aarush,,,,,Messenger
#
# "Dec 28, 2021 6:34:39pm",Aarush,Reacted ❤ to your message,5,,,Messenger
#
# "Dec 28, 2021 6:34:31pm",Samyukta,U want to be me so bad u were affecting bdays before u were born,15,,❤,Messenger
#
# "Dec 28, 2021 6:34:24pm",Aarush,,,,,Messenger
#
# "Dec 28, 2021 6:34:18pm",Samyukta,Omg really when,3,,,Messenger
#
# "Dec 28, 2021 6:34:17pm",Aarush,coincidence,1,,,Messenger
#
# "Dec 28, 2021 6:34:11pm",Aarush,my sister's bday is like next week,7,,,Messenger
#
# "Dec 28, 2021 6:34:03pm",Aarush,omfg,1,,,Messenger
#
# "Dec 28, 2021 6:34:02pm",Aarush,wait,1,,,Messenger
#
# "Dec 28, 2021 6:33:58pm",Aarush,yay thanks,2,,,Messenger
#
# "Dec 28, 2021 6:33:34pm",Samyukta,I told her u said happy birthday,7,,,Messenger
#
# "Dec 28, 2021 6:33:25pm",Aarush,why no bandar on it,5,,,Messenger
#
# "Dec 28, 2021 6:33:21pm",Aarush,,,,,Messenger
#
# "Dec 28, 2021 6:33:19pm",Samyukta,,,,,Messenger
#
# "Dec 28, 2021 6:33:17pm",Aarush,omg,1,,,Messenger
#
# "Dec 28, 2021 6:33:07pm",Samyukta,,,,,Messenger
#
# "Dec 28, 2021 6:32:58pm",Aarush,what'd u buy her,4,,,Messenger
#
# "Dec 28, 2021 6:32:48pm",Samyukta,,1,,,Messenger
#
# "Dec 28, 2021 6:32:47pm",Samyukta,Fixed my sisters present,4,,,Messenger
#
# "Dec 28, 2021 6:32:43pm",Samyukta,,,,,Messenger
#
# "Dec 28, 2021 6:32:29pm",Aarush,they call it the g spot,6,,,Messenger
#
# "Dec 28, 2021 6:32:23pm",Aarush,(gender),1,,,Messenger
#
# "Dec 28, 2021 6:32:20pm",Aarush,go to the g,4,,,Messenger
#
# "Dec 28, 2021 6:32:11pm",Aarush,uh,1,,,Messenger
#
# "Dec 28, 2021 6:32:10pm",Samyukta,oh my bad,3,,,Messenger
#
# "Dec 28, 2021 6:32:06pm",Aarush,yeah duh,2,,,Messenger
#
# "Dec 28, 2021 6:32:03pm",Samyukta,Do I have to renew it,6,,,Messenger
#
# "Dec 28, 2021 6:32:00pm",Samyukta,it must’ve expired,3,,,Messenger
#
# "Dec 28, 2021 6:31:41pm",Aarush,your opinion is invalid,4,,,Messenger
#
# "Dec 28, 2021 6:31:37pm",Aarush,shut up men don't exist,5,,,Messenger
#
# "Dec 28, 2021 6:31:30pm",Samyukta,No they don’t,3,,,Messenger
#
# "Dec 28, 2021 6:31:27pm",Samyukta,Oh I forgot to write ark,6,,,Messenger
#
# "Dec 28, 2021 6:31:25pm",Aarush,i disagree,2,,,Messenger
#
# "Dec 28, 2021 6:31:19pm",Aarush,spaces count as addition,4,,,Messenger
#
# "Dec 28, 2021 6:31:16pm",Samyukta,new^2*ark,1,,,Messenger
#
# "Dec 28, 2021 6:31:06pm",Aarush,when you distribute it,4,,,Messenger
#
# "Dec 28, 2021 6:31:02pm",Samyukta,so new newark = new*new*ark,5,,,Messenger
#
# "Dec 28, 2021 6:31:00pm",Aarush,yeah?,1,,,Messenger
#
# "Dec 28, 2021 6:30:44pm",Samyukta,As in new*ark,3,,,Messenger
#
# "Dec 28, 2021 5:32:31pm",Aarush,new(1+ark) library,2,,,Messenger
#
# "Dec 28, 2021 5:32:22pm",Aarush,so its,2,,,Messenger
#
# "Dec 28, 2021 5:32:16pm",Aarush,you factor out the new,5,,,Messenger
#
# "Dec 28, 2021 5:32:11pm",Aarush,? no,2,,,Messenger
#
# "Dec 28, 2021 5:13:30pm",Samyukta,new^2library,1,,,Messenger
#
# "Dec 28, 2021 5:13:24pm",Samyukta,the new newark library,4,,,Messenger
#
# "Dec 28, 2021 9:17:27am",Samyukta,"not yet,,,",2,,,Messenger
#
# "Dec 28, 2021 12:26:09am",Aarush,also omg HAPPY BIRTHDAY SHWEEN BEAND,6,,❤,Messenger
#
# "Dec 28, 2021 12:25:59am",Aarush,did you buy it,4,,,Messenger
#
# "Dec 26, 2021 5:57:23pm",Aarush,respond,1,,,Messenger
#
# "Dec 26, 2021 4:59:19pm",Samyukta,Respond,1,,,Messenger
#
# "Dec 25, 2021 10:35:51pm",Aarush,on god on god,4,,,Messenger
#
# "Dec 25, 2021 10:35:48pm",Aarush,fire!!!!,1,,,Messenger
#
# "Dec 25, 2021 10:35:26pm",Samyukta,"lo siento no se cual es ""fuergo"" solo se el fuego",11,,,Messenger
#
# "Dec 25, 2021 10:35:13pm",Aarush,*olvidar,1,,,Messenger
#
# "Dec 25, 2021 10:35:10pm",Aarush,please use forger instead of olvidsr,6,,❤,Messenger
#
# "Dec 25, 2021 10:34:54pm",Aarush,nosotros forgemos,2,,,Messenger
#
# "Dec 25, 2021 10:34:50pm",Aarush,yo fuergo,2,,,Messenger
#
# "Dec 25, 2021 10:34:46pm",Aarush,tu fuerges,2,,,Messenger
#
# "Dec 25, 2021 10:29:04pm",Samyukta,present tense...,2,,,Messenger
#
# "Dec 25, 2021 10:29:01pm",Samyukta,forger?,1,,,Messenger
#
# "Dec 25, 2021 10:28:54pm",Samyukta,i might forgor,3,,,Messenger
#
# "Dec 25, 2021 10:28:48pm",Samyukta,,1,,,Messenger
#
# "Dec 25, 2021 10:28:46pm",Samyukta,"i want to,",3,,,Messenger
#
# "Dec 25, 2021 10:27:39pm",Aarush,are y gonna go to allegro,6,,,Messenger
#
# "Dec 25, 2021 10:27:16pm",Aarush,,,,,Messenger
#
# "Dec 25, 2021 10:16:35pm",Samyukta,At least u secured the overcooked 2 for cheap,9,,,Messenger
#
# "Dec 25, 2021 10:16:27pm",Samyukta,Oh rip,2,,,Messenger
#
# "Dec 25, 2021 9:14:35pm",Aarush,ahaha,1,,,Messenger
#
# "Dec 25, 2021 9:14:33pm",Aarush,we were gonna go on vacation but,7,,,Messenger
#
# "Dec 25, 2021 9:14:26pm",Aarush,nothing lol,2,,,Messenger
#
# "Dec 25, 2021 9:11:54pm",Samyukta,Que te reglaron tus padres para navidad,7,,,Messenger
#
# "Dec 25, 2021 7:28:47pm",Aarush,,,,,Messenger
#
# "Dec 25, 2021 7:27:57pm",Samyukta,(I am being respectful of how u r peeing rn),10,,,Messenger
#
# "Dec 25, 2021 7:27:47pm",Samyukta,,1,,,Messenger
#
# "Dec 25, 2021 6:58:39pm",Aarush,,,,,Messenger
#
# "Dec 25, 2021 6:57:40pm",Samyukta,,,,,Messenger
#
# "Dec 25, 2021 4:16:22pm",Aarush,when youtube makes laundry reminder,5,,,Messenger
#
# "Dec 25, 2021 4:15:26pm",Samyukta,Also vid this week is me wearing that outfit,9,,,Messenger
#
# "Dec 25, 2021 4:15:00pm",Samyukta,Was previously wearing tje outfit present in my last two yt videos,12,,,Messenger
#
# "Dec 25, 2021 4:14:41pm",Aarush,i don't believe you ok,5,,,Messenger
#
# "Dec 25, 2021 4:14:31pm",Samyukta,,,,,Messenger
#
# "Dec 25, 2021 4:14:26pm",Samyukta,changed right before coming here’s,5,,,Messenger
#
# "Dec 25, 2021 4:14:12pm",Samyukta,Just for u,3,,,Messenger
#
# "Dec 25, 2021 4:14:00pm",Aarush,ur lying,2,,,Messenger
#
# "Dec 25, 2021 4:13:58pm",Aarush,no way,2,,,Messenger
#
# "Dec 25, 2021 4:13:57pm",Aarush,,1,,,Messenger
#
# "Dec 25, 2021 4:12:25pm",Samyukta,i wore fresh clothes,4,,,Messenger
#
# "Dec 25, 2021 4:01:38pm",Aarush,ok,1,,,Messenger
#
# "Dec 25, 2021 4:01:26pm",Samyukta,okay ill ealve rn then,5,,,Messenger
#
# "Dec 25, 2021 4:01:18pm",Samyukta,okay maybe i will just finish it when i get back,11,,,Messenger
#
# "Dec 25, 2021 4:01:13pm",Samyukta,but my mothers lunch has delyaed everything,7,,,Messenger
#
# "Dec 25, 2021 4:01:06pm",Samyukta,before coming to ur house,5,,,Messenger
#
# "Dec 25, 2021 4:01:03pm",Samyukta,i had plans to upload a video,7,,,Messenger
#
# "Dec 25, 2021 4:01:00pm",Aarush,omg what did u eat,5,,,Messenger
#
# "Dec 25, 2021 4:00:56pm",Samyukta,okay u know,3,,,Messenger
#
# "Dec 25, 2021 4:00:46pm",Samyukta,SHE WAS MAKING A NICE CHRISTMAS MEAL AND SHE DIDNT TELL ME,12,,,Messenger
#
# "Dec 25, 2021 4:00:44pm",Aarush,r u saying you're leaving rn or you will leave in 15,12,,,Messenger
#
# "Dec 25, 2021 4:00:28pm",Aarush,,1,,,Messenger
#
# "Dec 25, 2021 4:00:04pm",Samyukta,Rlly sorry my mom made lunch at like 3:30,9,,,Messenger
#
# "Dec 25, 2021 3:59:55pm",Samyukta,Actually I will come at like 4:15,7,,,Messenger
#
# "Dec 25, 2021 2:41:30pm",Aarush,,,,,Messenger
#
# "Dec 25, 2021 2:41:24pm",Samyukta,Sasha and Marcy dynamic,4,,,Messenger
#
# "Dec 25, 2021 2:41:11pm",Aarush,no lol i do this to you to,8,,,Messenger
#
# "Dec 25, 2021 2:41:02pm",Samyukta,Oh purr,2,,,Messenger
#
# "Dec 25, 2021 2:41:00pm",Samyukta,sorry for betraying,3,,,Messenger
#
# "Dec 25, 2021 2:40:57pm",Aarush,ok bitch that is super valid bitch,7,,,Messenger
#
# "Dec 25, 2021 2:40:55pm",Samyukta,Or 3/30,2,,,Messenger
#
# "Dec 25, 2021 2:40:35pm",Samyukta,,,,,Messenger
#
# "Dec 25, 2021 2:40:29pm",Samyukta,My mom kinda hasn’t make lunch yet,7,,,Messenger
#
# "Dec 25, 2021 2:28:09pm",Aarush,,1,,,Messenger
#
# "Dec 25, 2021 2:28:07pm",Aarush,hey bitch tell bitch me bitch when bitch you bitch leave bitch,12,,,Messenger
#
# "Dec 24, 2021 11:54:11pm",Aarush,of that post,3,,,Messenger
#
# "Dec 24, 2021 11:54:09pm",Aarush,reminding you,2,,,Messenger
#
# "Dec 24, 2021 11:54:07pm",Aarush,uh,1,,,Messenger
#
# "Dec 24, 2021 11:54:06pm",Aarush,bc i was,3,,,Messenger
#
# "Dec 24, 2021 11:54:02pm",Aarush,nooo i was amplifying he voice,6,,,Messenger
#
# "Dec 24, 2021 11:53:50pm",Samyukta,omggggg,1,,,Messenger
#
# "Dec 24, 2021 11:53:44pm",Aarush,life of vi post ref,5,,,Messenger
#
# "Dec 24, 2021 11:53:44pm",Samyukta,...,1,,,Messenger
#
# "Dec 24, 2021 11:53:42pm",Samyukta,y r u silencing women voices,6,,,Messenger
#
# "Dec 24, 2021 11:53:34pm",Aarush,sh,1,,,Messenger
#
# "Dec 24, 2021 11:53:33pm",Aarush,,1,,,Messenger
#
# "Dec 24, 2021 11:53:32pm",Aarush,aa,1,,,Messenger
#
# "Dec 24, 2021 11:52:05pm",Samyukta,ta,1,,,Messenger
#
# "Dec 24, 2021 11:52:04pm",Samyukta,yuk,1,,,Messenger
#
# "Dec 24, 2021 11:51:59pm",Samyukta,sam,1,,,Messenger
#
# "Dec 24, 2021 11:51:41pm",Aarush,i love women,3,,,Messenger
#
# "Dec 24, 2021 11:51:32pm",Aarush,OMG,1,,,Messenger
#
# "Dec 24, 2021 11:51:30pm",Aarush,omg,1,,,Messenger
#
# "Dec 24, 2021 11:51:14pm",Samyukta,have meow,2,,,Messenger
#
# "Dec 24, 2021 11:51:12pm",Samyukta,but women,2,,,Messenger
#
# "Dec 24, 2021 11:51:11pm",Samyukta,yea home doesn't have w in it no meow,9,,,Messenger
#
# "Dec 24, 2021 11:50:12pm",Aarush,arsonist core??,2,,,Messenger
#
# "Dec 24, 2021 11:50:06pm",Aarush,,1,,,Messenger
#
# "Dec 24, 2021 11:50:02pm",Samyukta,good thats whatt i wantd,5,,,Messenger
#
# "Dec 24, 2021 11:49:51pm",Aarush,this is incredibly rude to homos!!!!,6,,,Messenger
#
# "Dec 24, 2021 11:49:51pm",Samyukta,thanjana,1,,,Messenger
#
# "Dec 24, 2021 11:49:46pm",Samyukta,thanja,1,,,Messenger
#
# "Dec 24, 2021 11:49:43pm",Aarush,i am cancelling you !,5,,,Messenger
#
# "Dec 24, 2021 11:49:41pm",Samyukta,homopho bi,2,,,Messenger
#
# "Dec 24, 2021 11:49:39pm",Aarush,omg ! !,3,,,Messenger
#
# "Dec 24, 2021 11:49:37pm",Samyukta,im homophobi,2,,,Messenger
#
# "Dec 24, 2021 11:49:34pm",Samyukta,yea,1,,,Messenger
#
# "Dec 24, 2021 11:49:27pm",Samyukta,uh,1,,,Messenger
#
# "Dec 24, 2021 11:49:26pm",Samyukta,im,1,,,Messenger
#
# "Dec 24, 2021 11:49:25pm",Samyukta,,1,,,Messenger
#
# "Dec 24, 2021 11:49:22pm",Samyukta,im homophobic bc i hate homeless ppl because not homeowner no meow,12,,,Messenger
#
# "Dec 24, 2021 11:48:47pm",Aarush,see what,2,,,Messenger
#
# "Dec 24, 2021 11:48:27pm",Samyukta,i see now,3,,,Messenger
#
# "Dec 24, 2021 11:48:24pm",Aarush,,,,,Messenger
#
# "Dec 24, 2021 11:48:22pm",Samyukta,ohhh,1,,,Messenger
#
# "Dec 24, 2021 11:48:21pm",Samyukta,im homophobic,2,,,Messenger
#
# "Dec 24, 2021 11:48:15pm",Samyukta,never let me in govt,5,,,Messenger
#
# "Dec 24, 2021 11:48:08pm",Samyukta,i htae homless ppl,4,,,Messenger
#
# "Dec 24, 2021 11:48:05pm",Aarush,wow that is so magical,5,,,Messenger
#
# "Dec 24, 2021 11:48:03pm",Samyukta,omggg it all makes sense,5,,,Messenger
#
# "Dec 24, 2021 11:47:58pm",Aarush,omg,1,,,Messenger
#
# "Dec 24, 2021 11:47:52pm",Samyukta,,1,,,Messenger
#
# "Dec 24, 2021 11:47:48pm",Aarush,yes I did!!!!,3,,,Messenger
#
# "Dec 24, 2021 11:47:37pm",Samyukta,did u know tha,4,,,Messenger
#
# "Dec 24, 2021 11:47:33pm",Aarush,meow,1,,,Messenger
#
# "Dec 24, 2021 11:47:32pm",Aarush,and u can't spell homeowner witbout,6,,,Messenger
#
# "Dec 24, 2021 11:47:25pm",Aarush,it's bc she's a homeowner,5,,,Messenger
#
# "Dec 24, 2021 11:47:19pm",Aarush,btw i figured out why u like my mom so much,11,,,Messenger
#
# "Dec 24, 2021 11:47:08pm",Samyukta,ribbit,1,,,Messenger
#
# "Dec 24, 2021 11:47:05pm",Aarush,meow,1,,,Messenger
#
# "Dec 24, 2021 11:47:01pm",Samyukta,arf,1,,,Messenger
#
# "Dec 24, 2021 11:46:59pm",Samyukta,doggie,1,,,Messenger
#
# "Dec 24, 2021 11:46:53pm",Samyukta,3 is gud dawg,4,,,Messenger
#
# "Dec 24, 2021 11:44:01pm",Aarush,,1,,,Messenger
#
# "Dec 24, 2021 11:43:58pm",Aarush,wait what time do u want 2 meet mañana,9,,,Messenger
#
# "Dec 24, 2021 10:06:34pm",Aarush,king,1,,,Messenger
#
# "Dec 24, 2021 10:06:32pm",Aarush,slay,1,,,Messenger
#
# "Dec 24, 2021 10:06:31pm",Aarush,purr,1,,,Messenger
#
# "Dec 24, 2021 10:01:31pm",Samyukta,period,1,,,Messenger
#
# "Dec 24, 2021 9:48:15pm",Aarush,hot chocolate!!!,2,,,Messenger
#
# "Dec 24, 2021 9:48:08pm",Aarush,yay,1,,,Messenger
#
# "Dec 24, 2021 9:46:16pm",Samyukta,sure,1,,,Messenger
#
# "Dec 24, 2021 9:45:55pm",Samyukta,,,,,Messenger
#
# "Dec 24, 2021 9:45:49pm",Samyukta,Twinisies,1,,,Messenger
#
# "Dec 24, 2021 9:45:45pm",Samyukta,,,,,Messenger
#
# "Dec 24, 2021 9:45:45pm",Samyukta,,1,,,Messenger
#
# "Dec 24, 2021 9:45:41pm",Samyukta,Twonsies,1,,,Messenger
#
# "Dec 24, 2021 9:45:37pm",Samyukta,two does,2,,,Messenger
#
# "Dec 24, 2021 9:45:35pm",Samyukta,OMG I WAS GONNA ASK U,6,,,Messenger
#
# "Dec 24, 2021 9:43:10pm",Aarush,or do u have crismas plans,6,,,Messenger
#
# "Dec 24, 2021 9:43:01pm",Aarush,hey gorb would you be into coming over tomorrow for overcooked,11,,,Messenger
#
# "Dec 21, 2021 7:46:19pm",Aarush,yeah it's probably fine,4,,,Messenger
#
# "Dec 21, 2021 7:17:55pm",Samyukta,like is this fine,4,,,Messenger
#
# "Dec 21, 2021 7:17:42pm",Samyukta,does csp journal need to be full sentences,8,,,Messenger
#
# "Dec 17, 2021 5:14:11pm",Samyukta,thanks king,2,,,Messenger
#
# "Dec 17, 2021 5:14:10pm",Samyukta,yayy it worked,3,,,Messenger
#
# "Dec 17, 2021 5:13:09pm",Aarush,done,1,,,Messenger
#
# "Dec 17, 2021 5:12:16pm",Aarush,,1,,,Messenger
#
# "Dec 17, 2021 5:12:09pm",Samyukta,tell me wehn u do,5,,,Messenger
#
# "Dec 17, 2021 5:11:24pm",Samyukta,unregister then,2,,,Messenger
#
# "Dec 17, 2021 5:11:22pm",Samyukta,oh okay,2,,,Messenger
#
# "Dec 17, 2021 5:10:47pm",Aarush,i think that's it,4,,,Messenger
#
# "Dec 17, 2021 5:10:46pm",Aarush,,,,,Messenger
#
# "Dec 17, 2021 5:10:30pm",Samyukta,loggin in hold on,4,,,Messenger
#
# "Dec 17, 2021 5:10:20pm",Samyukta,oh,1,,,Messenger
#
# "Dec 17, 2021 5:10:15pm",Aarush,no i think you can dude,6,,,Messenger
#
# "Dec 17, 2021 5:10:09pm",Samyukta,just drop ur sat it's fine,6,,,Messenger
#
# "Dec 17, 2021 5:10:05pm",Samyukta,i don't think i can switch locations,7,,,Messenger
#
# "Dec 17, 2021 5:10:01pm",Samyukta,wait acutally i already registered,5,,,Messenger
#
# "Dec 17, 2021 5:09:49pm",Samyukta,,1,,,Messenger
#
# "Dec 17, 2021 5:09:47pm",Samyukta,yea sure,2,,,Messenger
#
# "Dec 17, 2021 4:36:34pm",Aarush,want to get it out of the way before i forgor,11,,,Messenger
#
# "Dec 17, 2021 4:36:23pm",Aarush,hey dude let me know if you can do the sat switch pls,13,,,Messenger
#
# "Dec 16, 2021 7:08:33pm",Samyukta,oh i read this wrong lol sorry,7,,,Messenger
#
# "Dec 16, 2021 6:56:29pm",Aarush,i can understand why you would want to go somewhere else,11,,,Messenger
#
# "Dec 16, 2021 6:56:15pm",Aarush,like we're always loud when it trying to work so,10,,,Messenger
#
# "Dec 16, 2021 6:56:06pm",Aarush,nonono my point is,4,,,Messenger
#
# "Dec 16, 2021 6:55:38pm",Samyukta,do u not want me to come to liu flex?,10,,,Messenger
#
# "Dec 16, 2021 6:42:04pm",Aarush,i was expecting you to say that,7,,,Messenger
#
# "Dec 16, 2021 6:39:36pm",Samyukta,?,1,,,Messenger
#
# "Dec 16, 2021 6:06:41pm",Aarush,ngl i was kinda just waiting for you to say this,11,,,Messenger
#
# "Dec 16, 2021 6:06:32pm",Aarush,,1,,,Messenger
#
# "Dec 16, 2021 6:02:54pm",Samyukta,maybe like once in a while,6,,,Messenger
#
# "Dec 16, 2021 6:02:45pm",Samyukta,i dn't think it matters much cause u have pranav but i don't think i'll come to liu flex much anymore,21,,,Messenger
#
# "Dec 13, 2021 7:32:30pm",Aarush,cuz pranav asked,3,,,Messenger
#
# "Dec 13, 2021 7:32:27pm",Aarush,ok I'm gonna go to Benedetti flex tomorrow,8,,,Messenger
#
# "Dec 13, 2021 7:00:25pm",Aarush,i don't think you need to write it,8,,,Messenger
#
# "Dec 13, 2021 6:59:07pm",Samyukta,maybe i will just write it in data,8,,,Messenger
#
# "Dec 13, 2021 6:59:03pm",Samyukta,,,,,Messenger
#
# "Dec 13, 2021 6:34:02pm",Aarush,what precautions are there,4,,,Messenger
#
# "Dec 13, 2021 6:32:56pm",Samyukta,is there a specific place where i put the safety precautions in the lab,14,,,Messenger
#
# "Dec 13, 2021 4:34:40pm",Aarush,ambiguity core (it was not your fault and i take full responsibility thanks bub),14,,,Messenger
#
# "Dec 13, 2021 4:33:25pm",Samyukta,,,,,Messenger
#
# "Dec 13, 2021 4:33:23pm",Samyukta,,1,,,Messenger
#
# "Dec 13, 2021 4:33:22pm",Samyukta,yes,1,,,Messenger
#
# "Dec 13, 2021 4:33:20pm",Aarush,,,,,Messenger
#
# "Dec 13, 2021 4:33:15pm",Aarush,so do we need to???,5,,,Messenger
#
# "Dec 13, 2021 4:25:11pm",Samyukta,Yes she did,3,,,Messenger
#
# "Dec 13, 2021 4:15:02pm",Aarush,did Liu say if we needed to do the lab prep,11,,,Messenger
#
# "Dec 12, 2021 11:05:37pm",Aarush,THANKS FOR SHARING,3,,❤,Messenger
#
# "Dec 12, 2021 11:05:34pm",Aarush,OMGGGH,1,,,Messenger
#
# "Dec 12, 2021 10:58:31pm",Samyukta,https://www.youtube.com/watch?v=7RY0Cbj3_WM,1,,,Messenger
#
# "Dec 10, 2021 10:07:28am",Samyukta,,,,,Messenger
#
# "Dec 10, 2021 8:32:34am",Aarush,nothing,1,,,Messenger
#
# "Dec 10, 2021 8:30:09am",Samyukta,?,1,,,Messenger
#
# "Dec 10, 2021 8:12:32am",Aarush,gorb,1,,,Messenger
#
# "Dec 10, 2021 8:12:09am",Aarush,This message was unsent,4,,,Messenger
#
# "Dec 07, 2021 9:44:06pm",Samyukta,okay bestie logging on RN to like thema ll,9,,,Messenger
#
# "Dec 07, 2021 9:43:55pm",Aarush,my tweets are all FLOPPING :(,6,,,Messenger
#
# "Dec 07, 2021 9:43:46pm",Aarush,,,,,Messenger
#
# "Dec 07, 2021 9:43:44pm",Samyukta,or dono't like ur tweet,5,,,Messenger
#
# "Dec 07, 2021 9:43:42pm",Aarush,Reacted ❤ to your message,5,,,Messenger
#
# "Dec 07, 2021 9:43:39pm",Samyukta,or burn your house,4,,,Messenger
#
# "Dec 07, 2021 9:43:34pm",Samyukta,"just like how you're the ""victim"" when i steal your computer",11,,❤,Messenger
#
# "Dec 07, 2021 9:43:32pm",Aarush,ur gay /pos,3,,,Messenger
#
# "Dec 07, 2021 9:43:13pm",Samyukta,victimizer,1,,,Messenger
#
# "Dec 07, 2021 9:43:07pm",Samyukta,when did i ever negatively comment on that??,8,,,Messenger
#
# "Dec 07, 2021 9:42:59pm",Samyukta,and i have to do my homework,7,,,Messenger
#
# "Dec 07, 2021 9:42:55pm",Samyukta,cause ramirez taught it badly,5,,,Messenger
#
# "Dec 07, 2021 9:24:47pm",Aarush,and then have the audacity to comment on how I WATCH calc videos,13,,,Messenger
#
# "Dec 07, 2021 9:24:37pm",Aarush,why r u watching a video about it,8,,,Messenger
#
# "Dec 07, 2021 9:24:16pm",Samyukta,she spelled it l'hospital let's goooo french erasure :),9,,,Messenger
#
# "Dec 07, 2021 9:05:59pm",Aarush,gosh I'm so bad at yhis,6,,,Messenger
#
# "Dec 07, 2021 8:46:38pm",Samyukta,but something,2,,,Messenger
#
# "Dec 07, 2021 8:46:36pm",Samyukta,i don't know if it will be a coherent word,10,,,Messenger
#
# "Dec 07, 2021 8:46:30pm",Samyukta,u will say something,4,,,Messenger
#
# "Dec 07, 2021 8:46:25pm",Samyukta,just maybe,2,,,Messenger
#
# "Dec 07, 2021 8:46:24pm",Samyukta,and maybe,2,,,Messenger
#
# "Dec 07, 2021 8:46:20pm",Samyukta,i have faith that pranav will talk to her,9,,,Messenger
#
# "Dec 07, 2021 8:24:40pm",Aarush,talk to her,3,,,Messenger
#
# "Dec 07, 2021 8:24:37pm",Aarush,gosh I'm surprised you have such faith in me yo,10,,,Messenger
#
# "Dec 07, 2021 8:17:29pm",Samyukta,ur canon twitter crush,4,,,Messenger
#
# "Dec 07, 2021 8:17:18pm",Samyukta,...,1,,,Messenger
#
# "Dec 07, 2021 8:17:16pm",Samyukta,go to rossie tomorrow go talk to,7,,,Messenger
#
# "Dec 06, 2021 11:48:17pm",Aarush,pratty ho Raha hai,4,,❤,Messenger
#
# "Dec 06, 2021 11:48:05pm",Samyukta,in ush,2,,,Messenger
#
# "Dec 06, 2021 11:48:04pm",Samyukta,party party,2,,,Messenger
#
# "Dec 06, 2021 11:48:02pm",Samyukta,partyush,1,,,Messenger
#
# "Dec 06, 2021 11:47:52pm",Aarush,prattyush,1,,❤,Messenger
#
# "Dec 06, 2021 11:47:33pm",Samyukta,pratty crazy LEOL,3,,,Messenger
#
# "Dec 06, 2021 11:47:25pm",Aarush,i am pratty????,3,,,Messenger
#
# "Dec 06, 2021 11:47:18pm",Samyukta,,,,,Messenger
#
# "Dec 06, 2021 11:47:16pm",Samyukta,i hoep this was encouraging,5,,,Messenger
#
# "Dec 06, 2021 11:47:02pm",Samyukta,This message was unsent,4,,,Messenger
#
# "Dec 06, 2021 11:46:59pm",Samyukta,"pratyush got 1440 on psat, 1560 on sat",8,,,Messenger
#
# "Dec 06, 2021 9:36:31pm",Aarush,wtf sridharan ref irl,4,,❤,Messenger
#
# "Dec 06, 2021 9:34:46pm",Samyukta,u should collab with the universe and form the metaverse,10,,,Messenger
#
# "Dec 06, 2021 9:34:40pm",Samyukta,no ur not,3,,,Messenger
#
# "Dec 06, 2021 9:34:39pm",Samyukta,no,1,,,Messenger
#
# "Dec 06, 2021 9:34:37pm",Samyukta,yes,1,,,Messenger
#
# "Dec 06, 2021 9:17:52pm",Aarush,am i the universe,4,,,Messenger
#
# "Dec 06, 2021 9:17:40pm",Aarush,lmao,1,,,Messenger
#
# "Dec 06, 2021 9:17:25pm",Samyukta,universe hates me a lot,5,,,Messenger
#
# "Dec 06, 2021 9:17:20pm",Samyukta,okay okay ur right,4,,,Messenger
#
# "Dec 06, 2021 9:17:12pm",Aarush,I swear it's only weird if you make it weird,10,,,Messenger
#
# "Dec 06, 2021 9:17:01pm",Samyukta,pur thanks king,3,,,Messenger
#
# "Dec 06, 2021 9:17:01pm",Aarush,yeah also she hated chem so,6,,❤,Messenger
#
# "Dec 06, 2021 9:16:56pm",Aarush,whatever just don't let it affect you,7,,,Messenger
#
# "Dec 06, 2021 9:16:53pm",Samyukta,probably not chem? cause i wouldve seen her in lab,10,,,Messenger
#
# "Dec 06, 2021 9:16:43pm",Samyukta,idk what it's for,4,,,Messenger
#
# "Dec 06, 2021 9:16:39pm",Aarush,like for chem?????,3,,,Messenger
#
# "Dec 06, 2021 9:16:37pm",Samyukta,yea,1,,,Messenger
#
# "Dec 06, 2021 9:16:35pm",Aarush,,1,,,Messenger
#
# "Dec 06, 2021 9:16:29pm",Samyukta,and the universe hates me,5,,,Messenger
#
# "Dec 06, 2021 9:16:25pm",Aarush,also for 6 she mentioned total num of ions,9,,,Messenger
#
# "Dec 06, 2021 9:16:25pm",Samyukta,and she is presenting at the thing i am rpesenting at tomorrow,12,,,Messenger
#
# "Dec 06, 2021 9:16:14pm",Samyukta,tanvi goes to asdrp,4,,,Messenger
#
# "Dec 06, 2021 9:16:09pm",Samyukta,okay thanks,2,,,Messenger
#
# "Dec 06, 2021 9:16:08pm",Aarush,i think,2,,,Messenger
#
# "Dec 06, 2021 9:16:05pm",Aarush,also for 6 you should put ur moles into ions,10,,,Messenger
#
# "Dec 06, 2021 9:15:55pm",Aarush,i agree w all except 5 for which i got 54,11,,,Messenger
#
# "Dec 06, 2021 8:18:46pm",Samyukta,Okay Thank you for your time. I look forward to more long bisexual messages in the future.,17,,,Messenger
#
# "Dec 06, 2021 8:18:34pm",Samyukta,9. 300.0 mL,3,,,Messenger
#
# "Dec 06, 2021 8:18:19pm",Samyukta,3.13 * 10^-2 mol for number of chloride ions in 25 mL of b,14,,,Messenger
#
# "Dec 06, 2021 8:18:03pm",Samyukta,9.17 * 10 ^ -3 mol SO4 2-,8,,,Messenger
#
# "Dec 06, 2021 8:16:41pm",Samyukta,i will send just check if u want,8,,,Messenger
#
# "Dec 06, 2021 8:16:36pm",Samyukta,would u like 2 check answers for molarity worksheet,9,,,Messenger
#
# "Dec 06, 2021 5:43:00pm",Aarush,,,,,Messenger
#
# "Dec 06, 2021 5:13:03pm",Samyukta,patito,1,,,Messenger
#
# "Dec 06, 2021 5:13:00pm",Samyukta,PONDerable,1,,,Messenger
#
# "Dec 06, 2021 5:12:52pm",Samyukta,is it orbacious and ponderable,5,,,Messenger
#
# "Dec 06, 2021 5:12:33pm",Aarush,that's not gorbalicious,3,,,Messenger
#
# "Dec 06, 2021 5:12:06pm",Samyukta,im not reading that,4,,,Messenger
#
# "Dec 06, 2021 5:12:04pm",Samyukta,or sorry,2,,,Messenger
#
# "Dec 06, 2021 5:11:46pm",Aarush,amusement),1,,,Messenger
#
# "Dec 06, 2021 5:08:20pm",Samyukta,guey,1,,,Messenger
#
# "Dec 06, 2021 5:08:19pm",Samyukta,today at school i heard a guy speaking spanish say guye,11,,,Messenger
#
# "Dec 05, 2021 8:04:29pm",Samyukta,but ur a mix of blacks and whites,8,,,Messenger
#
# "Dec 05, 2021 8:04:21pm",Samyukta,i know ur straight,4,,,Messenger
#
# "Dec 05, 2021 8:04:11pm",Aarush,no I'm a grey person inside pk,7,,,Messenger
#
# "Dec 05, 2021 8:03:58pm",Aarush,yoo,1,,,Messenger
#
# "Dec 05, 2021 8:03:57pm",Samyukta,THIS IS UGLIER,3,,,Messenger
#
# "Dec 05, 2021 8:03:55pm",Samyukta,NO IT WASNT IT WAS CUTE,6,,,Messenger
#
# "Dec 05, 2021 8:03:49pm",Aarush,it was so ugly omg,5,,,Messenger
#
# "Dec 05, 2021 7:38:11pm",Samyukta,WHYD U DELETE UR FACEBOOK PFP :(,7,,,Messenger
#
# "Dec 05, 2021 7:38:06pm",Samyukta,QUESTION,1,,,Messenger
#
# "Nov 27, 2021 12:20:10am",Aarush,,,,,Messenger
#
# "Nov 27, 2021 12:20:00am",Aarush,,,,,Messenger
#
# "Nov 27, 2021 12:20:00am",Samyukta,,,,,Messenger
#
# "Nov 27, 2021 12:20:00am",Samyukta,,,,,Messenger
#
# "Nov 27, 2021 12:20:00am",Samyukta,,,,,Messenger
#
# "Nov 27, 2021 12:19:59am",Samyukta,,,,,Messenger
#
# "Nov 27, 2021 12:19:56am",Aarush,,,,,Messenger
#
# "Nov 27, 2021 12:19:50am",Aarush,darcy,1,,,Messenger
#
# "Nov 27, 2021 12:19:48am",Aarush,farty,1,,,Messenger
#
# "Nov 27, 2021 12:19:47am",Aarush,hello,1,,,Messenger
#
# "Oct 14, 2021 10:45:24pm",Aarush,,,,,Messenger
#
# "Oct 14, 2021 10:28:27pm",Samyukta,,1,,,Messenger
#
# "Sep 20, 2021 10:10:40pm",Samyukta,u,1,,,Messenger
#
# "Aug 22, 2021 3:16:04pm",Samyukta,#life,1,,,Messenger
#
# "Aug 22, 2021 3:13:48pm",Aarush,nooo,1,,,Messenger
#
# "Aug 22, 2021 3:13:46pm",Aarush,wait,1,,,Messenger
#
# "Aug 22, 2021 3:13:45pm",Aarush,wtf,1,,,Messenger
#
# "Aug 22, 2021 3:13:42pm",Aarush,,,,,Messenger
#
# "Aug 22, 2021 3:13:27pm",Samyukta,only u can cancel urself,5,,,Messenger
#
# "Aug 22, 2021 3:13:23pm",Samyukta,x/x = 1,3,,,Messenger
#
# "Aug 22, 2021 3:13:21pm",Samyukta,because like in a fractoin,5,,,Messenger
#
# "Aug 22, 2021 3:13:15pm",Samyukta,which is really deep,4,,,Messenger
#
# "Aug 22, 2021 3:13:13pm",Samyukta,the only person who can cancel u is urself,9,,,Messenger
#
# "Aug 22, 2021 3:13:07pm",Samyukta,,1,,,Messenger
#
# "Aug 22, 2021 3:13:06pm",Aarush,why aren't u mad,4,,,Messenger
#
# "Aug 22, 2021 3:12:56pm",Samyukta,oh okay,2,,,Messenger
#
# "Aug 22, 2021 3:12:53pm",Aarush,i cancelled u in my mind,6,,,Messenger
#
# "Aug 22, 2021 3:12:48pm",Samyukta,noooooo,1,,,Messenger
#
# "Aug 22, 2021 3:12:45pm",Aarush,ur cancelled,2,,,Messenger
#
# "Aug 22, 2021 3:12:44pm",Samyukta,,,,,Messenger
#
# "Aug 22, 2021 3:12:42pm",Aarush,,,,,Messenger
#
# "Aug 22, 2021 3:12:41pm",Aarush,yrs,1,,,Messenger
#
# "Aug 22, 2021 3:12:37pm",Samyukta,did u get my email,5,,,Messenger
#
# ,Aarush,good,1,,,Messenger
#
# "Aug 22, 2021 3:12:30pm",Samyukta,,,,,Messenger
#
# "Aug 22, 2021 3:12:22pm",Samyukta,I LIKE IT,3,,,Messenger
#
# "Aug 22, 2021 3:12:20pm",Samyukta,,1,,,Messenger
#
# "Aug 22, 2021 3:12:07pm",Samyukta,got it,2,,,Messenger
#
# "Aug 22, 2021 3:12:02pm",Samyukta,i am waiting for anotifcation,5,,,Messenger
#
# "Aug 22, 2021 3:11:50pm",Aarush,check now,2,,,Messenger
#
# "Aug 22, 2021 3:11:06pm",Samyukta,besides email,2,,,Messenger
#
# "Aug 22, 2021 3:11:05pm",Samyukta,messenger is the only thing i have notiifcations for,9,,,Messenger
#
# "Aug 22, 2021 3:10:32pm",Aarush,wait give me a second i didn't think u would respond right away,13,,,Messenger
#
# "Aug 22, 2021 3:10:28pm",Samyukta,can u send to samyukta.athreya@gmail.com,5,,,Messenger
#
# "Aug 22, 2021 3:10:15pm",Samyukta,which email,2,,,Messenger
#
# "Aug 22, 2021 3:09:54pm",Aarush,i kinda hate it but you can be the judge,10,,,Messenger
#
# "Aug 22, 2021 3:09:45pm",Aarush,tried to do the carpet,5,,,Messenger
#
# "Aug 22, 2021 3:09:38pm",Aarush,ok check ur email i,5,,,Messenger
#
# "Aug 22, 2021 11:51:09am",Samyukta,,1,,,Messenger
#
# "Aug 22, 2021 11:51:05am",Samyukta,asap,1,,,Messenger
#
# "Aug 21, 2021 5:33:24pm",Aarush,harigoo,1,,,Messenger
#
# "Jun 30, 2021 9:59:49am",Samyukta,,,,,Messenger
#
# "Jun 30, 2021 9:59:47am",Samyukta,,,,,Messenger
#
# "May 24, 2021 2:15:58pm",Samyukta,(im also mrs and mr boonchuys wife),7,,,Messenger
#
# "May 24, 2021 2:15:44pm",Samyukta,im a mario,3,,,Messenger
#
# "May 24, 2021 10:45:10am",Aarush,I'm a bandarist,3,,,Messenger
#
# "May 24, 2021 10:44:56am",Aarush,,,,,Messenger
#
# "May 24, 2021 10:44:51am",Aarush,,,,,Messenger
#
# "May 24, 2021 10:25:46am",Samyukta,sorry I’m a leftist,4,,,Messenger
#
# "May 24, 2021 9:03:20am",Aarush,that's right,2,,,Messenger
#
# "May 24, 2021 9:03:15am",Aarush,,1,,,Messenger
#
# "May 24, 2021 9:03:10am",Aarush,This message was unsent,4,,,Messenger
#
# "May 24, 2021 9:03:07am",Aarush,This message was unsent,4,,,Messenger
#
# "May 24, 2021 9:00:18am",Samyukta,Aarush give me ur number,5,,,Messenger
#
# "Apr 19, 2021 5:40:38pm",Aarush,the one with the blue gear icon,7,,,Messenger
#
# "Apr 19, 2021 5:37:18pm",Samyukta,Which one should I get,5,,,Messenger
#
# "Apr 19, 2021 5:37:14pm",Samyukta,bruh i looked up steam on Apple store and there are so many different apps,15,,,Messenger
#
# "Apr 08, 2021 5:55:25pm",Samyukta,anaya,1,,,Messenger
#
# "Apr 08, 2021 5:55:22pm",Samyukta,marsha,1,,,Messenger
#
# "Apr 08, 2021 5:55:20pm",Samyukta,sashini,1,,,Messenger
#
# "Apr 08, 2021 5:55:20pm",Aarush,sashini,1,,,Messenger
#
# "Apr 08, 2021 5:55:11pm",Aarush,,,,,Messenger
#
# "Apr 08, 2021 5:30:26pm",Samyukta,,1,,,Messenger
#
# "Apr 08, 2021 5:30:21pm",Samyukta,season 2 is marsha's season,5,,,Messenger
#
# "Apr 08, 2021 5:30:16pm",Samyukta,season 1 was anne's season,5,,,Messenger
#
# "Apr 08, 2021 5:30:11pm",Samyukta,matt said in the stream that,6,,,Messenger
#
# "Mar 25, 2021 5:25:08pm",Samyukta,,,,,Messenger
#
# "Mar 25, 2021 5:07:37pm",Aarush,,,,,Messenger
#
# "Mar 25, 2021 5:07:25pm",Aarush,that was so funnioso,4,,,Messenger
#
# "Mar 25, 2021 5:07:20pm",Aarush,wait i never saw these,5,,,Messenger
#
# "Mar 21, 2021 10:28:09pm",Samyukta,sory,1,,,Messenger
#
# "Mar 21, 2021 10:28:04pm",Samyukta,wait i'll just send them to my sister :),9,,,Messenger
#
# "Mar 21, 2021 10:27:58pm",Samyukta,sorry for spqmming have to save these somewhere,8,,,Messenger
#
# "Mar 21, 2021 10:24:53pm",Samyukta,,,,,Messenger
#
# "Mar 21, 2021 10:21:28pm",Samyukta,,1,,,Messenger
#
# "Mar 21, 2021 10:20:39pm",Samyukta,,,,,Messenger
#
# "Mar 21, 2021 10:20:30pm",Samyukta,just saving for now,4,,,Messenger
#
# "Mar 21, 2021 10:20:28pm",Samyukta,i quit discord today but im going to put these there tomorrow,12,,,Messenger
#
# "Mar 21, 2021 10:20:24pm",Samyukta,,,,,Messenger
#
# "Mar 21, 2021 10:13:48pm",Samyukta,which is still a pretty low standard,7,,,Messenger
#
# "Mar 21, 2021 10:13:37pm",Samyukta,like it would have to be better than the actual twoh episodes,12,,,Messenger
#
# "Mar 21, 2021 10:13:30pm",Aarush,,,,,Messenger
#
# "Mar 21, 2021 10:13:29pm",Samyukta,unless it's like really really relaly really really good,9,,,Messenger
#
# "Mar 21, 2021 10:13:23pm",Samyukta,i will find something in the soundtrack to criticize and say i could've done better,15,,,Messenger
#
# "Mar 21, 2021 10:13:03pm",Aarush,tell me if it's any good,6,,,Messenger
#
# "Mar 21, 2021 9:59:10pm",Samyukta,but i bet my tl is gonna be flooded w it,11,,,Messenger
#
# "Mar 21, 2021 9:59:04pm",Samyukta,,1,,,Messenger
#
# "Mar 21, 2021 9:58:53pm",Samyukta,i don't know,3,,,Messenger
#
# "Mar 21, 2021 9:57:44pm",Aarush,when,1,,,Messenger
#
# "Mar 21, 2021 9:52:25pm",Samyukta,i'll probably hate watch it,5,,,Messenger
#
# "Mar 21, 2021 9:52:14pm",Samyukta,i don't know it's not out yet,7,,,Messenger
#
# "Mar 21, 2021 9:49:20pm",Aarush,is it good,3,,,Messenger
#
# "Mar 21, 2021 9:49:03pm",Aarush,tF,1,,,Messenger
#
# "Mar 21, 2021 9:47:33pm",Samyukta,?????,1,,,Messenger
#
# "Mar 21, 2021 9:47:31pm",Samyukta,with TEN ORGINAL SONGS,4,,,Messenger
#
# "Mar 21, 2021 9:47:30pm",Aarush,holy heckles,2,,,Messenger
#
# "Mar 21, 2021 9:47:27pm",Aarush,wait what,2,,,Messenger
#
# "Mar 21, 2021 9:47:27pm",Samyukta,a musical,2,,,Messenger
#
# "Mar 21, 2021 9:47:25pm",Aarush,,1,,,Messenger
#
# "Mar 21, 2021 9:47:21pm",Samyukta,like the fans made it,5,,,Messenger
#
# "Mar 21, 2021 9:47:18pm",Samyukta,nonono,1,,,Messenger
#
# "Mar 21, 2021 9:47:08pm",Aarush,holy shit a show makes episodes,6,,,Messenger
#
# "Mar 21, 2021 9:46:06pm",Samyukta,https://www.youtube.com/watch?v=mXaWH4fnsFo,1,,,Messenger
#
# "Mar 21, 2021 9:46:05pm",Samyukta,THE EPISODE IS GONNA END UP BETTER THAN THE SHOW ITSELF BRUH,12,,,Messenger
#
# "Mar 21, 2021 9:45:58pm",Samyukta,ARE YOU KIDDING THE SHOW IS TRASH,7,,,Messenger
#
# "Mar 21, 2021 9:45:54pm",Samyukta,THEY DEADASS MADE A TW//THE OWL HOUSE EPISODE???,8,,,Messenger
#
# "Mar 06, 2021 10:54:49pm",Samyukta,damn okay,2,,,Messenger
#
# "Mar 06, 2021 10:35:23pm",Aarush,the drums are actually good volume,6,,,Messenger
#
# "Mar 06, 2021 10:35:17pm",Aarush,with headphones,2,,,Messenger
#
# "Mar 06, 2021 10:35:15pm",Aarush,i was listening on my phone i just listened on my computer,12,,,Messenger
#
# "Mar 06, 2021 10:35:01pm",Aarush,wait actually,2,,,Messenger
#
# "Mar 06, 2021 10:18:11pm",Samyukta,kk,1,,,Messenger
#
# "Mar 06, 2021 10:17:59pm",Aarush,raise the piano too,4,,,Messenger
#
# "Mar 06, 2021 10:17:41pm",Aarush,yeah,1,,,Messenger
#
# "Mar 06, 2021 10:17:18pm",Samyukta,u always say lower drum,5,,,Messenger
#
# "Mar 06, 2021 10:17:13pm",Samyukta,u literally hate drums,4,,,Messenger
#
# "Mar 06, 2021 10:17:09pm",Samyukta,oh ok,2,,,Messenger
#
# "Mar 06, 2021 10:17:05pm",Aarush,no the drums,3,,,Messenger
#
# "Mar 06, 2021 10:17:04pm",Samyukta,or the b ass,4,,,Messenger
#
# "Mar 06, 2021 10:17:02pm",Aarush,maybe lower the dying,4,,,Messenger
#
# "Mar 06, 2021 10:17:00pm",Samyukta,like the piano,3,,,Messenger
#
# "Mar 06, 2021 10:16:57pm",Samyukta,which part,2,,,Messenger
#
# "Mar 06, 2021 10:16:52pm",Aarush,the start is a little intense,6,,,Messenger
#
# "Mar 06, 2021 10:16:38pm",Samyukta,thanks bith,2,,,Messenger
#
# "Mar 06, 2021 10:16:31pm",Aarush,the vibe are perfect,4,,,Messenger
#
# "Mar 06, 2021 10:15:07pm",Samyukta,i shent,2,,,Messenger
#
# "Mar 06, 2021 10:14:12pm",Aarush,yeah sure,2,,,Messenger
#
# "Mar 06, 2021 10:14:09pm",Samyukta,it is kinda shit right now because i just made it,11,,,Messenger
#
# "Mar 06, 2021 10:14:09pm",Aarush,you just made an ass of you and me,9,,,Messenger
#
# "Mar 06, 2021 10:14:04pm",Samyukta,want to hear the loop i made,7,,,Messenger
#
# "Mar 06, 2021 10:13:44pm",Samyukta,don't worry bob i can be of ass istance,9,,,Messenger
#
# "Mar 06, 2021 10:13:37pm",Samyukta,stories are fun to make,5,,,Messenger
#
# "Mar 06, 2021 10:13:29pm",Aarush,game design,2,,,Messenger
#
# "Mar 06, 2021 10:13:25pm",Aarush,"rather ""story""",2,,,Messenger
#
# "Mar 06, 2021 10:13:20pm",Aarush,story,1,,,Messenger
#
# "Mar 06, 2021 10:13:15pm",Aarush,i mean it's not just music,6,,,Messenger
#
# "Mar 06, 2021 10:13:06pm",Samyukta,might as well feel productive,5,,,Messenger
#
# "Mar 06, 2021 10:13:03pm",Samyukta,i make music all the time anyways,7,,,Messenger
#
# "Mar 06, 2021 10:12:58pm",Aarush,sex,1,,,Messenger
#
# "Mar 06, 2021 10:12:57pm",Samyukta,yes i would love to,5,,,Messenger
#
# "Mar 06, 2021 10:12:48pm",Aarush,and we could come up with ideas together,8,,,Messenger
#
# "Mar 06, 2021 10:12:40pm",Samyukta,yea ofc,2,,,Messenger
#
# "Mar 06, 2021 10:12:36pm",Aarush,like you do music,4,,,Messenger
#
# "Mar 06, 2021 10:12:31pm",Aarush,in doing a game jam with me sometime,8,,,Messenger
#
# "Mar 06, 2021 10:12:14pm",Aarush,would you be interested,4,,,Messenger
#
# "Mar 06, 2021 10:12:14pm",Samyukta,oh u actually had something to ask,7,,,Messenger
#
# "Mar 06, 2021 10:12:03pm",Aarush,don't feel obligated to say yes but,7,,,Messenger
#
# "Mar 06, 2021 10:11:50pm",Samyukta,not,1,,,Messenger
#
# "Mar 06, 2021 10:11:48pm",Samyukta,what is it,3,,,Messenger
#
# "Mar 06, 2021 10:11:42pm",Samyukta,no,1,,,Messenger
#
# "Mar 06, 2021 10:11:39pm",Aarush,omg sex,2,,,Messenger
#
# "Mar 06, 2021 10:11:36pm",Aarush,can i ask you something,5,,,Messenger
#
# "Mar 06, 2021 10:11:32pm",Samyukta,i am making music for minigame in amphibia,8,,,Messenger
#
# "Mar 06, 2021 10:11:23pm",Samyukta,yes,1,,,Messenger
#
# "Mar 06, 2021 10:11:11pm",Aarush,Bob,1,,,Messenger
#
# "Mar 06, 2021 10:10:50pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 10:10:46pm",Samyukta,true,1,,,Messenger
#
# "Mar 06, 2021 9:23:15pm",Aarush,after the factory,3,,,Messenger
#
# "Mar 06, 2021 9:23:07pm",Aarush,frobo only comes,3,,,Messenger
#
# "Mar 06, 2021 9:23:04pm",Aarush,also,1,,,Messenger
#
# "Mar 06, 2021 9:23:02pm",Aarush,yeah,1,,,Messenger
#
# "Mar 06, 2021 8:37:49pm",Samyukta,wait nvm i think frobo was just looking up at the tree,12,,,Messenger
#
# "Mar 06, 2021 8:36:36pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 8:36:36pm",Samyukta,Oh true,2,,,Messenger
#
# "Mar 06, 2021 8:36:27pm",Samyukta,Because frobo has to take off its head to see,10,,,Messenger
#
# "Mar 06, 2021 8:36:18pm",Samyukta,I think there is somebody inside frobo,7,,,Messenger
#
# "Mar 06, 2021 8:36:14pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 7:30:11pm",Aarush,no hay problema,3,,,Messenger
#
# "Mar 06, 2021 7:30:07pm",Aarush,you can flip it in photoshop,6,,,Messenger
#
# "Mar 06, 2021 7:28:21pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 7:28:14pm",Samyukta,ugh just realIed we should’ve done from the opposite direction,10,,,Messenger
#
# "Mar 06, 2021 7:27:49pm",Samyukta,thanks bub,2,,,Messenger
#
# "Mar 06, 2021 7:17:11pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 7:16:56pm",Aarush,i think these were the best ones,7,,,Messenger
#
# "Mar 06, 2021 7:16:53pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 4:13:43pm",Aarush,sex,1,,,Messenger
#
# "Mar 06, 2021 4:13:03pm",Samyukta,kk empiezo ahora,3,,,Messenger
#
# "Mar 06, 2021 4:13:02pm",Aarush,yeah,1,,,Messenger
#
# "Mar 06, 2021 4:12:58pm",Aarush,i left,2,,,Messenger
#
# "Mar 06, 2021 4:12:53pm",Samyukta,oh r u starting now,5,,,Messenger
#
# "Mar 06, 2021 4:12:12pm",Aarush,Bob,1,,,Messenger
#
# "Mar 06, 2021 4:08:12pm",Aarush,,1,,,Messenger
#
# "Mar 06, 2021 4:04:40pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 4:04:39pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 4:04:38pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 4:04:34pm",Samyukta,and I’m assuming u have smaller feet than me,9,,,Messenger
#
# "Mar 06, 2021 4:04:32pm",Aarush,i don't want ur crusty crocs,6,,,Messenger
#
# "Mar 06, 2021 4:04:19pm",Aarush,i live bandar emogi,4,,,Messenger
#
# "Mar 06, 2021 4:04:19pm",Samyukta,I actually have a spare pair of crocs,8,,,Messenger
#
# "Mar 06, 2021 4:04:12pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 4:04:09pm",Aarush,i don't trust your shortcuts,5,,,Messenger
#
# "Mar 06, 2021 4:04:07pm",Samyukta,(It will be longer),4,,,Messenger
#
# "Mar 06, 2021 4:04:03pm",Aarush,my crocs are too small bith,6,,,Messenger
#
# "Mar 06, 2021 4:03:59pm",Samyukta,,1,,,Messenger
#
# "Mar 06, 2021 4:03:51pm",Samyukta,can u just wear crocs like a normal person,9,,,Messenger
#
# "Mar 06, 2021 4:03:46pm",Aarush,let's take the trail it will be fastest,8,,,Messenger
#
# "Mar 06, 2021 4:03:38pm",Aarush,ill tell u when my shoes r dry,8,,,Messenger
#
# "Mar 06, 2021 4:03:35pm",Samyukta,ew no,2,,,Messenger
#
# "Mar 06, 2021 4:03:30pm",Aarush,blame the rain,3,,,Messenger
#
# "Mar 06, 2021 4:03:25pm",Aarush,nvm I'm not apologizing,4,,,Messenger
#
# "Mar 06, 2021 4:03:25pm",Samyukta,"when should I start, bith",5,,,Messenger
#
# "Mar 06, 2021 4:03:19pm",Aarush,sorry bith,2,,,Messenger
#
# "Mar 06, 2021 4:03:10pm",Samyukta,Okay bith,2,,,Messenger
#
# "Mar 06, 2021 3:59:41pm",Aarush,can u give me 15 minutes while i wait for them to dry,13,,,Messenger
#
# "Mar 06, 2021 3:59:28pm",Aarush,my shoes were out in the rain last night and now they r wet,14,,,Messenger
#
# "Mar 06, 2021 3:59:00pm",Aarush,,1,,,Messenger
#
# "Mar 06, 2021 3:58:56pm",Aarush,ugh bob,2,,,Messenger
#
# "Mar 06, 2021 3:47:18pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 3:46:42pm",Aarush,ok bubitos,2,,,Messenger
#
# "Mar 06, 2021 3:46:08pm",Samyukta,Leave at 4,3,,,Messenger
#
# "Mar 06, 2021 3:40:36pm",Aarush,meet at 4 or leave at 4,7,,,Messenger
#
# "Mar 06, 2021 3:40:18pm",Aarush,bob,1,,,Messenger
#
# "Mar 06, 2021 3:24:29pm",Samyukta,true,1,,,Messenger
#
# "Mar 06, 2021 3:19:20pm",Aarush,ur trash,2,,,Messenger
#
# "Mar 06, 2021 3:19:18pm",Aarush,not even a good fancam,5,,,Messenger
#
# "Mar 06, 2021 3:19:14pm",Aarush,it was just memes ok,5,,,Messenger
#
# "Mar 06, 2021 3:15:04pm",Samyukta,ur not even grateful for the yunnan fancam hush,9,,,Messenger
#
# "Mar 06, 2021 3:14:47pm",Samyukta,,1,,,Messenger
#
# "Mar 06, 2021 3:14:45pm",Samyukta,omg i wish my sister gaymed,6,,,Messenger
#
# "Mar 06, 2021 3:14:06pm",Aarush,the trailer was more than enough u bitch,8,,,Messenger
#
# "Mar 06, 2021 3:13:57pm",Aarush,ok I'm gonna play mario with my sister for like 30 min so if i don't respond that's why,19,,,Messenger
#
# "Mar 06, 2021 3:13:45pm",Samyukta,but only after sasha flashbacks,5,,,Messenger
#
# "Mar 06, 2021 3:13:41pm",Samyukta,it would work,3,,,Messenger
#
# "Mar 06, 2021 3:13:39pm",Samyukta,okay actually,2,,,Messenger
#
# "Mar 06, 2021 3:12:36pm",Aarush,singing chigjug,2,,,Messenger
#
# "Mar 06, 2021 3:12:31pm",Aarush,like baby british boy,4,,,Messenger
#
# "Mar 06, 2021 3:12:27pm",Aarush,baby sadha,2,,,Messenger
#
# "Mar 06, 2021 3:12:25pm",Aarush,yeah but,2,,,Messenger
#
# "Mar 06, 2021 3:12:06pm",Samyukta,i don't understand the benefit,5,,,Messenger
#
# "Mar 06, 2021 3:12:01pm",Samyukta,,1,,,Messenger
#
# "Mar 06, 2021 3:12:00pm",Samyukta,and she's not a dilf,5,,,Messenger
#
# "Mar 06, 2021 3:11:57pm",Samyukta,five secondsn of screen time,5,,,Messenger
#
# "Mar 06, 2021 3:11:53pm",Samyukta,baby sasha literally has,4,,,Messenger
#
# "Mar 06, 2021 3:11:31pm",Aarush,or baby sasha,3,,,Messenger
#
# "Mar 06, 2021 3:11:29pm",Aarush,sasha would've been best,4,,,Messenger
#
# "Mar 06, 2021 3:10:54pm",Samyukta,she should've done grime or something,6,,,Messenger
#
# "Mar 06, 2021 3:10:48pm",Samyukta,yea that's what i thought,5,,,Messenger
#
# "Mar 06, 2021 3:10:28pm",Aarush,ok garnets video is kinda trash yunnan doesn't have enough screentime to have bariety,14,,,Messenger
#
# "Mar 06, 2021 3:10:23pm",Samyukta,"no im not, misgendering is bad",6,,,Messenger
#
# "Mar 06, 2021 3:09:08pm",Aarush,that's you're being a lad,5,,,Messenger
#
# "Mar 06, 2021 3:09:01pm",Aarush,and glad,2,,,Messenger
#
# "Mar 06, 2021 3:08:59pm",Aarush,,1,,,Messenger
#
# "Mar 06, 2021 3:08:57pm",Aarush,bandar mama is mad,4,,,Messenger
#
# "Mar 06, 2021 3:08:53pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 3:08:21pm",Samyukta,okay im making it offensive.,5,,,Messenger
#
# "Mar 06, 2021 3:08:11pm",Samyukta,drawing romantic sashanne jug chugging,5,,,Messenger
#
# "Mar 06, 2021 3:08:10pm",Aarush,it's only offensive if u make it offensive,8,,,Messenger
#
# "Mar 06, 2021 3:08:01pm",Aarush,no i only said bandar,5,,,Messenger
#
# "Mar 06, 2021 3:07:55pm",Samyukta,like the chikalisk thing,4,,,Messenger
#
# "Mar 06, 2021 3:07:52pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 3:07:52pm",Samyukta,cause we are assuming all monkeys are bandar mama,9,,,Messenger
#
# "Mar 06, 2021 3:07:42pm",Aarush,how would it be offensive,5,,,Messenger
#
# "Mar 06, 2021 3:07:41pm",Samyukta,liar,1,,,Messenger
#
# "Mar 06, 2021 3:07:36pm",Aarush,,1,,,Messenger
#
# "Mar 06, 2021 3:07:32pm",Samyukta,wait is this ofensive,4,,,Messenger
#
# "Mar 06, 2021 3:07:29pm",Samyukta,YAY,1,,,Messenger
#
# "Mar 06, 2021 3:07:23pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 3:07:23pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 3:07:23pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 3:07:23pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 3:07:21pm",Samyukta,,,,,Messenger
#
# "Mar 06, 2021 3:07:19pm",Samyukta,wait r u texting me from instagram,7,,,Messenger
#
# "Mar 06, 2021 3:06:20pm",Aarush,bandar,1,,,Messenger
#
# "Mar 06, 2021 3:06:17pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 3:06:16pm",Aarush,Aarush set the quick reaction to     .,11,,,Messenger
#
# "Mar 06, 2021 3:05:55pm",Aarush,,1,,,Messenger
#
# "Mar 06, 2021 3:05:48pm",Aarush,Aarush changed the theme to Berry,6,,,Messenger
#
# "Mar 06, 2021 3:05:41pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 3:04:45pm",Samyukta,omg let's rob him :D,5,,,Messenger
#
# "Mar 06, 2021 3:04:28pm",Aarush,my uncle might be there hee hee,7,,,Messenger
#
# "Mar 06, 2021 3:04:03pm",Samyukta,"if we can't get fresh donut-bagel-ejaculations for cheap, let's buy samosa from dulhan",13,,,Messenger
#
# "Mar 06, 2021 3:03:43pm",Aarush,but i think it is overpriced tbh,7,,,Messenger
#
# "Mar 06, 2021 3:03:37pm",Aarush,yifang is also in that area,6,,,Messenger
#
# "Mar 06, 2021 3:03:37pm",Samyukta,so he told me there weren't any,7,,,Messenger
#
# "Mar 06, 2021 3:03:30pm",Samyukta,maybe my dad just didn't want me to eat donuts,10,,,Messenger
#
# "Mar 06, 2021 3:03:25pm",Samyukta,okay they might sell donuts actually,6,,,Messenger
#
# "Mar 06, 2021 3:03:17pm",Samyukta,and i remember their bagels are godly,7,,,Messenger
#
# "Mar 06, 2021 3:03:15pm",Aarush,,1,,,Messenger
#
# "Mar 06, 2021 3:03:14pm",Aarush,oh shit what,3,,,Messenger
#
# "Mar 06, 2021 3:03:10pm",Samyukta,they sell bagels,3,,,Messenger
#
# "Mar 06, 2021 3:03:08pm",Samyukta,their shop is clickbait,4,,,Messenger
#
# "Mar 06, 2021 3:03:02pm",Samyukta,THEY DON'T FOR SOME REASON,5,,,Messenger
#
# "Mar 06, 2021 3:02:57pm",Samyukta,ah yes i see you are a man of complexity,10,,,Messenger
#
# "Mar 06, 2021 3:02:41pm",Aarush,*do-ejaculates,1,,,Messenger
#
# "Mar 06, 2021 3:02:27pm",Aarush,wait don't they also sell donuts,6,,,Messenger
#
# "Mar 06, 2021 3:02:16pm",Aarush,i mean,2,,,Messenger
#
# "Mar 06, 2021 3:02:13pm",Samyukta,i'll ask beforehadn tho fs,5,,,Messenger
#
# "Mar 06, 2021 3:02:10pm",Samyukta,so idk how much they'll charge,6,,,Messenger
#
# "Mar 06, 2021 3:02:05pm",Samyukta,and covid,2,,,Messenger
#
# "Mar 06, 2021 3:02:04pm",Samyukta,,1,,,Messenger
#
# "Mar 06, 2021 3:01:54pm",Samyukta,yea that's fine,3,,,Messenger
#
# "Mar 06, 2021 3:01:49pm",Aarush,ill bring like 7 and if that's not enough i won't get anything,13,,,Messenger
#
# "Mar 06, 2021 3:01:38pm",Aarush,yeah,1,,,Messenger
#
# "Mar 06, 2021 3:01:36pm",Aarush,not even sure if i have that much but ill see,11,,,Messenger
#
# "Mar 06, 2021 3:01:33pm",Samyukta,"if they really charge that much, im not buying tho",10,,,Messenger
#
# "Mar 06, 2021 3:01:23pm",Samyukta,like just in case,4,,,Messenger
#
# "Mar 06, 2021 3:01:17pm",Aarush,whoa 10 ok,3,,,Messenger
#
# "Mar 06, 2021 3:01:12pm",Samyukta,i will bring a 20,5,,,Messenger
#
# "Mar 06, 2021 3:01:03pm",Samyukta,uh probably like ten,4,,,Messenger
#
# "Mar 06, 2021 3:00:59pm",Samyukta,+1 class,2,,,Messenger
#
# "Mar 06, 2021 3:00:55pm",Aarush,wait should I bring money and if so how much,10,,,Messenger
#
# "Mar 06, 2021 3:00:48pm",Samyukta,,1,,,Messenger
#
# "Mar 06, 2021 3:00:44pm",Samyukta,her redeeming quality is,4,,,Messenger
#
# "Mar 06, 2021 3:00:29pm",Samyukta,which is like 12093481029348123098 class deduction,6,,,Messenger
#
# "Mar 06, 2021 3:00:24pm",Samyukta,and she makes twoh content,5,,,Messenger
#
# "Mar 06, 2021 3:00:23pm",Aarush,how dare u,3,,,Messenger
#
# "Mar 06, 2021 3:00:21pm",Samyukta,which is like a two class deduction,7,,,Messenger
#
# "Mar 06, 2021 3:00:20pm",Aarush,she makes twoh content,4,,,Messenger
#
# "Mar 06, 2021 3:00:15pm",Samyukta,but she also ships marc*nne,5,,,Messenger
#
# "Mar 06, 2021 3:00:10pm",Samyukta,her content is good,4,,,Messenger
#
# "Mar 06, 2021 2:59:23pm",Aarush,that youre not even allowed to compete with her,9,,,Messenger
#
# "Mar 06, 2021 2:59:10pm",Aarush,she is so far below everyone in content,8,,,Messenger
#
# "Mar 06, 2021 2:58:59pm",Aarush,youtube is like thay,4,,,Messenger
#
# "Mar 06, 2021 2:58:54pm",Aarush,,1,,,Messenger
#
# "Mar 06, 2021 2:58:46pm",Aarush,no she doesnt,3,,,Messenger
#
# "Mar 06, 2021 2:58:35pm",Samyukta,garnet107 has competish,3,,,Messenger
#
# "Mar 06, 2021 2:58:28pm",Samyukta,you didn't tw// repetition,4,,,Messenger
#
# "Mar 06, 2021 2:58:22pm",Aarush,please omg,2,,,Messenger
#
# "Mar 06, 2021 2:58:16pm",Aarush,ur just being a tw//sjw sjw,6,,,Messenger
#
# "Mar 06, 2021 2:58:06pm",Samyukta,im going to draw sasha chugging jug with grime,9,,,Messenger
#
# "Mar 06, 2021 2:57:56pm",Samyukta,which is so homophobic,4,,,Messenger
#
# "Mar 06, 2021 2:57:54pm",Samyukta,okay u can't on laptop,5,,,Messenger
#
# "Mar 06, 2021 2:57:43pm",Aarush,haha get fucked,3,,,Messenger
#
# "Mar 06, 2021 2:57:42pm",Samyukta,omg what,2,,,Messenger
#
# "Mar 06, 2021 2:57:36pm",Samyukta,i mean in the reactions to messagers,7,,,Messenger
#
# "Mar 06, 2021 2:57:28pm",Aarush,,1,,,Messenger
#
# ,Samyukta,why is there no fire emoji on messenger that is literlaly homophobic,12,,,Messenger
#
# "Mar 06, 2021 2:57:20pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 2:57:19pm",Aarush,i think,2,,,Messenger
#
# "Mar 06, 2021 2:57:15pm",Aarush,ugh why did she just make some banger content,9,,,Messenger
#
# "Mar 06, 2021 2:57:05pm",Aarush,omg,1,,,Messenger
#
# "Mar 06, 2021 2:57:03pm",Aarush,motto: ill leave bitches for u,6,,❤,Messenger
#
# "Mar 06, 2021 2:57:00pm",Samyukta,sex ok,2,,,Messenger
#
# "Mar 06, 2021 2:56:51pm",Samyukta,https://www.youtube.com/watch?v=hz0lCrZfbqY,1,,,Messenger
#
# "Mar 06, 2021 2:56:48pm",Samyukta,also new garnet107 video,4,,,Messenger
#
# "Mar 06, 2021 2:56:44pm",Aarush,let's just do 4 if we are gonna bike,9,,,Messenger
#
# "Mar 06, 2021 2:55:32pm",Samyukta,"also lets meet at 3:30 I just ate and if I do physical exercise, I am going to vomit",19,,,Messenger
#
# "Mar 06, 2021 2:54:34pm",Samyukta,so selfless,2,,,Messenger
#
# "Mar 06, 2021 2:54:27pm",Samyukta,you’re too kind,3,,,Messenger
#
# "Mar 06, 2021 2:20:04pm",Aarush,*plebs,1,,,Messenger
#
# "Mar 06, 2021 2:19:59pm",Aarush,also i gotta same some for the rest of you pleba,11,,,Messenger
#
# "Mar 06, 2021 2:19:49pm",Aarush,it's dangerous,2,,,Messenger
#
# "Mar 06, 2021 2:19:37pm",Aarush,can't have too many girls clamoring over me at once yk,11,,,Messenger
#
# "Mar 06, 2021 2:02:56pm",Samyukta,do you mean you don't want peopel to instantly fall in love with you,14,,,Messenger
#
# "Mar 06, 2021 1:29:49pm",Aarush,no i don't want people to think I'm weird,9,,,Messenger
#
# "Mar 06, 2021 1:26:03pm",Samyukta,(main),1,,,Messenger
#
# "Mar 06, 2021 1:26:01pm",Samyukta,or post on ur instagram,5,,,Messenger
#
# "Mar 06, 2021 1:25:54pm",Samyukta,change ur facebook pfp to this,6,,,Messenger
#
# "Mar 06, 2021 1:20:59pm",Samyukta,i am putting thes ein my camera roll btw,9,,,Messenger
#
# "Mar 06, 2021 1:15:24pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 1:14:54pm",Aarush,i just picked the hottest one,6,,,Messenger
#
# "Mar 06, 2021 1:14:43pm",Aarush,i have no idea,4,,,Messenger
#
# "Mar 06, 2021 1:14:19pm",Samyukta,what is that filter,4,,,Messenger
#
# "Mar 06, 2021 1:14:14pm",Samyukta,OMGGG,1,,,Messenger
#
# "Mar 06, 2021 1:12:29pm",Aarush,boom,1,,,Messenger
#
# "Mar 06, 2021 1:12:28pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 1:07:29pm",Aarush,i odnt owkn,3,,,Messenger
#
# "Mar 06, 2021 1:07:06pm",Samyukta,then why the ufkc ur proof or residency bith,9,,,Messenger
#
# "Mar 06, 2021 1:06:54pm",Aarush,bith,1,,,Messenger
#
# "Mar 06, 2021 1:06:50pm",Aarush,fuck u i live in a villa,7,,,Messenger
#
# "Mar 06, 2021 1:06:38pm",Samyukta,we get it u llive in a house,8,,,Messenger
#
# "Mar 06, 2021 1:06:31pm",Aarush,do u want a sequel to that,7,,,Messenger
#
# "Mar 06, 2021 1:06:26pm",Samyukta,^,1,,,Messenger
#
# "Mar 06, 2021 1:06:20pm",Samyukta,i thought it woudl be the sequel to this,9,,,Messenger
#
# "Mar 06, 2021 1:06:16pm",Aarush,it's good info,3,,,Messenger
#
# "Mar 06, 2021 1:06:14pm",Samyukta,wgen i saw that u sent a photo,8,,,Messenger
#
# "Mar 06, 2021 1:06:07pm",Samyukta,why did u send that,5,,,Messenger
#
# "Mar 06, 2021 1:04:32pm",Aarush,,,,,Messenger
#
# "Mar 06, 2021 1:04:13pm",Aarush,te entiendo,2,,,Messenger
#
# "Mar 06, 2021 1:04:08pm",Aarush,ok bubito,2,,,Messenger
#
# "Mar 06, 2021 1:01:37pm",Samyukta,"dk if i can do exactly 3, maybe 3:15 or osmething",11,,,Messenger
#
# "Mar 06, 2021 1:01:28pm",Samyukta,so im sayin ghere,4,,,Messenger
#
# "Mar 06, 2021 1:01:24pm",Samyukta,it said my texts aren't sending,6,,,Messenger
#
# "Mar 04, 2021 5:57:00pm",Samyukta,I meant twby,3,,,Messenger
#
# "Mar 04, 2021 5:48:48pm",Aarush,did u mean rwby,4,,,Messenger
#
# "Mar 04, 2021 5:32:05pm",Samyukta,this was a plotline in ruby,6,,,Messenger
#
# "Mar 04, 2021 2:40:55pm",Aarush,I'm insecure of my hotness,5,,,Messenger
#
# "Mar 04, 2021 2:40:46pm",Aarush,all the bitches are ignoring me for being too hot,10,,,Messenger
#
# "Mar 04, 2021 2:40:30pm",Aarush,can u stop commenting on my bitch count,8,,,Messenger
#
# "Mar 04, 2021 2:35:16pm",Samyukta,U could land hop pop fs,6,,,Messenger
#
# "Mar 04, 2021 2:35:04pm",Samyukta,Why do u have zero bitches when u look like this :(,12,,,Messenger
#
# "Mar 04, 2021 2:13:14pm",Aarush,i was gonna send one more,6,,,Messenger
#
# "Mar 04, 2021 2:13:09pm",Aarush,can't believe you,3,,,Messenger
#
# "Mar 04, 2021 2:13:04pm",Aarush,ur so fucking fakr,4,,,Messenger
#
# "Mar 04, 2021 2:07:13pm",Samyukta,THAT IS SO SEXY HOW COME I DIDNT SEE BEFORE,10,,,Messenger
#
# "Feb 24, 2021 3:02:17pm",Aarush,don't ignor,2,,,Messenger
#
# "Feb 24, 2021 3:02:15pm",Aarush,hey mamazzz,2,,,Messenger
#
# "Feb 24, 2021 3:02:02pm",Aarush,This message was unsent,4,,,Messenger
#
# "Feb 24, 2021 3:02:01pm",Aarush,,,,,Messenger
#
# "Feb 24, 2021 3:01:29pm",Samyukta,thanks,1,,,Messenger
#
# "Feb 24, 2021 3:01:23pm",Aarush,i will cherish,3,,,Messenger
#
# "Feb 24, 2021 3:01:18pm",Aarush,never,1,,,Messenger
#
# "Feb 24, 2021 3:01:03pm",Samyukta,,1,,,Messenger
#
# "Feb 24, 2021 2:58:09pm",Aarush,ignore,1,,,Messenger
#
# "Feb 24, 2021 2:58:00pm",Aarush,,,,,Messenger
#
# "Jan 28, 2021 5:57:04pm",Aarush,thatth thad,2,,,Messenger
#
# "Jan 28, 2021 5:56:59pm",Aarush,oh,1,,,Messenger
#
# "Jan 28, 2021 5:44:56pm",Samyukta,thu thouldnt thunderthand,3,,,Messenger
#
# "Jan 28, 2021 5:39:19pm",Aarush,who ith thith thathanne,4,,,Messenger
#
# "Jan 28, 2021 5:37:05pm",Samyukta,sasanne canon,2,,,Messenger
#
# "Jan 28, 2021 5:37:01pm",Samyukta,i only nerd for sasanne,5,,,Messenger
#
# "Jan 28, 2021 5:36:47pm",Aarush,thranger,1,,,Messenger
#
# "Jan 28, 2021 5:36:42pm",Aarush,yeth,1,,,Messenger
#
# "Jan 28, 2021 5:35:41pm",Aarush,u don't have a litjp,5,,,Messenger
#
# "Jan 28, 2021 5:35:33pm",Aarush,thatth not how a lithp workth,6,,,Messenger
#
# "Jan 28, 2021 5:35:32pm",Samyukta,thuck u u tarted tis,5,,,Messenger
#
# "Jan 28, 2021 5:35:22pm",Aarush,haha thucker,2,,,Messenger
#
# "Jan 28, 2021 5:35:18pm",Samyukta,fuck thu,2,,,Messenger
#
# "Jan 28, 2021 5:35:12pm",Samyukta,oh no ur lisp is conthagiis,6,,,Messenger
#
# "Jan 28, 2021 5:34:46pm",Samyukta,bro stop fucking gaslighting me you dumbass motherfucking moterhfucker,9,,,Messenger
#
# "Jan 28, 2021 5:34:24pm",Aarush,thop lying!,2,,,Messenger
#
# "Jan 28, 2021 5:34:20pm",Samyukta,what does htat make you,5,,,Messenger
#
# "Jan 28, 2021 5:34:17pm",Samyukta,you literally just said the fuck word to someone u don't even know,13,,,Messenger
#
# "Jan 28, 2021 5:34:08pm",Samyukta,bro u literally have a lisp u fucking nerd,9,,,Messenger
#
# "Jan 28, 2021 5:33:59pm",Aarush,bro i don't even know u and u called me a nerd,12,,,Messenger
#
# "Jan 28, 2021 5:33:48pm",Samyukta,very good yaar,3,,,Messenger
#
# "Jan 28, 2021 5:33:45pm",Aarush,,,,,Messenger
#
# "Jan 28, 2021 5:33:44pm",Samyukta,,,,,Messenger
#
# "Jan 28, 2021 5:33:43pm",Aarush,,,,,Messenger
#
# "Jan 28, 2021 5:33:39pm",Aarush,,,,,Messenger
#
# "Jan 28, 2021 5:33:35pm",Aarush,,,,,Messenger
#
# "Jan 28, 2021 5:33:34pm",Samyukta,equalty,1,,,Messenger
#
# "Jan 28, 2021 5:33:33pm",Aarush,,,,,Messenger
#
# "Jan 28, 2021 5:33:21pm",Samyukta,,,,,Messenger
#
# "Jan 28, 2021 5:33:13pm",Samyukta,cuz u r a nerd,5,,,Messenger
#
# "Jan 28, 2021 5:31:24pm",Aarush,supersammy,1,,,Messenger
#
# "Jan 28, 2021 5:31:22pm",Aarush,some-y? sammy?,2,,,Messenger
#
# "Jan 28, 2021 5:31:16pm",Aarush,if you sing the word some you get some-y,9,,,Messenger
#
# "Jan 28, 2021 5:30:59pm",Aarush,only some,2,,,Messenger
#
# "Jan 28, 2021 5:30:53pm",Aarush,superman can only handle a little kryptonite before falling,9,,,Messenger
#
# "Jan 28, 2021 5:30:27pm",Aarush,like superman,2,,,Messenger
#
# "Jan 28, 2021 5:30:24pm",Aarush,some super heroes have super in front of their name,10,,,Messenger
#
# "Jan 28, 2021 5:30:14pm",Aarush,"lambs are animals, like humans",5,,,Messenger
#
# "Jan 28, 2021 5:30:11pm",Samyukta,quirky spellign,2,,,Messenger
#
# "Jan 28, 2021 5:30:07pm",Samyukta,but uk,2,,,Messenger
#
# "Jan 28, 2021 5:30:06pm",Samyukta,it's actually pronounced samantha,4,,,Messenger
#
# "Jan 28, 2021 5:29:57pm",Samyukta,so russian,2,,,Messenger
#
# "Jan 28, 2021 5:29:55pm",Samyukta,omg it DOES,3,,,Messenger
#
# "Jan 28, 2021 5:29:54pm",Aarush,that white name is sam,5,,,Messenger
#
# "Jan 28, 2021 5:29:48pm",Aarush,ew,1,,,Messenger
#
# "Jan 28, 2021 5:29:47pm",Samyukta,fake,1,,,Messenger
#
# "Jan 28, 2021 5:29:46pm",Aarush,so naturally samyukta sounds like a white name,8,,,Messenger
#
# "Jan 28, 2021 5:29:45pm",Samyukta,it's samfuckta,2,,,Messenger
#
# "Jan 28, 2021 5:29:42pm",Samyukta,no,1,,,Messenger
#
# "Jan 28, 2021 5:29:34pm",Aarush,ur name is samtukta,4,,,Messenger
#
# "Jan 28, 2021 5:16:26pm",Samyukta,omg how did you know,5,,,Messenger
#
# "Jan 27, 2021 9:31:40pm",Aarush,r u the shupershammy,4,,,Messenger
#
# "Jan 27, 2021 9:23:26pm",Samyukta,omg are you like worldstar famous animator aarush agte????,9,,,Messenger
#
# "Jan 27, 2021 8:32:47pm",Aarush,"hey,, i don't know u lol,, let's be friends?",9,,,Messenger
#
# "Sep 19, 2019 6:39:34pm",Samyukta,You are now connected on Messenger,6,,,Messenger

# %%
msngr_df = pd.read_csv(path_csv_grouped)
msngr_df.drop(index=msngr_df.index[0], axis=0, inplace=True) 

print(msngr_df.duplicated().sum())
#drop duplicates
msngr_df.drop_duplicates(inplace = True)

#make sure there are no duplicates left
print(msngr_df.duplicated().sum())
# Out:
# 5
# 0

# %%
# Function to convert date format
def convert_date_format(date_str):
    try:
        # Convert the date string to a datetime object
        dt = pd.to_datetime(date_str, format='%b %d, %Y %I:%M:%S%p')
        # Convert datetime object to the desired format
        return dt.strftime('%Y-%m-%d %H:%M:%S')
    except ValueError:
        # If the date format is incorrect or not parseable, return the original string
        return date_str

# Apply the conversion function to the 'date' column
msngr_df['date'] = msngr_df['date'].apply(convert_date_format)

# %%
print(msngr_df.columns)
#date,user,text,word count,reactions,platform
df = msngr_df[['date', 'user', 'text', 'word count', 'reactions', 'platform']]
print(df.duplicated().sum())
df.to_csv(path_csv_separate)
# Out:
# Index(['date', 'user', 'text', 'word count', 'number of separated texts',
#        'reactions', 'platform'],
#       dtype='object')
# 0

# %%
# get number of separated texts

#'date', 'user', 'text', 'word count', 'number of separated texts', 'reactions', 'game pigeon', 'platform'
#group all the texts from one user that are next to each other in the csv. 
#the text column should have all the texts from that user combined into one string and separated by \n
#the number of separated texts column should have the number of rows that were merged

# Function to combine consecutive messages from the same user
def combine_consecutive_messages(df):
    # Create a column to mark groups of consecutive rows with the same user
    df['group'] = (df['user'] != df['user'].shift()).cumsum()
    
    # Group by 'user' and 'group', and aggregate the texts and count of messages
    result_df = df.groupby(['user', 'group']).agg({
        'text': lambda x: '\n'.join(x),  # Combine texts with newline separator
        'user': 'size'  # Count number of rows merged
    }).rename(columns={'user': 'number of separated texts'})
    
    # Reset index to convert 'user' and 'group' to columns
    result_df = result_df.reset_index()
    
    # Drop the 'group' column as it is no longer needed
    result_df = result_df.drop(columns=['group'])
    
    return result_df
msngr_df['text'] = msngr_df['text'].fillna('')
msngr_df['group'] = (msngr_df['user'] != msngr_df['user'].shift()).cumsum()
msngr_df['number of separated texts'] = msngr_df['group']
result_df = msngr_df.groupby(['user', 'group']).agg({
    'date' : 'first',
    'text': lambda x: '\n'.join(x),  # Combine texts with newline separator
    'word count' : 'sum',
    'user': 'size',  # Count number of rows merged,
    'reactions' : 'first',
    'platform' : 'first'
}).rename(columns={'user': 'number of separated texts'})

#['date', 'user', 'text', 'word count', 'number of separated texts', 'reactions', 'type of reply', 'platform']

# Reset index to convert group columns back to regular columns
result_df = result_df.reset_index()
result_df = result_df.sort_values(by='date')
result_df = result_df.drop('group', axis = 1)

# %%
print(result_df.head())
# Out:
#          user                 date  \
# 420  Samyukta  2019-09-19 18:39:34
# 209    Aarush  2021-01-27 20:32:47
# 419  Samyukta  2021-01-27 21:23:26
# 208    Aarush  2021-01-27 21:31:40
# 418  Samyukta  2021-01-28 17:16:26
#
#                                                   text  word count  \
# 420                 You are now connected on Messenger         6.0
# 209       hey,, i don't know u lol,, let's be friends?         9.0
# 419  omg are you like worldstar famous animator aar...         9.0
# 208                               r u the shupershammy         4.0
# 418                               omg how did you know         5.0
#
#      number of separated texts reactions   platform
# 420                          1      None  Messenger
# 209                          1      None  Messenger
# 419                          1      None  Messenger
# 208                          1      None  Messenger
# 418                          1      None  Messenger

# %%
#swap the order of columns so that date comes first
new_column_order = ['date', 'user'] + [col for col in result_df.columns if col not in ['date', 'user']]

# Reorder DataFrame columns
result_df = result_df[new_column_order]

# %%
print(result_df.tail())
# Out:
#                     date      user  \
# 211  2023-01-12 13:51:21  Samyukta
# 0    2023-01-12 13:52:42    Aarush
# 210  2023-01-12 13:58:31  Samyukta
# 111                 None    Aarush
# 390                 None  Samyukta
#
#                                                   text  word count  \
# 211  ALSO HE IS RISEN IS JUST EASTER\nThis is killi...        17.0
# 0    THATS WHY IT WAS FUNNY\nlike string theory\nOM...        10.0
# 210                            SH i connected the dots         5.0
# 111                                               good         1.0
# 390  why is there no fire emoji on messenger that i...        12.0
#
#      number of separated texts reactions   platform
# 211                          4      None  Messenger
# 0                            3      None  Messenger
# 210                          1      None  Messenger
# 111                          1      None  Messenger
# 390                          1      None  Messenger

# %%
result_df.to_csv(path_csv_grouped)
